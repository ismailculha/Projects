# %% [markdown]
# # AUTOSCOUT CAPSTONE PROJECT

# %% [markdown]
# <img src=https://i.ibb.co/wJW61Y2/Used-cars.jpg width="700" height="200">

# %% [markdown]
# ## Introduction
# Welcome to "***AutoScout Data Analysis Project***". This is the capstone project of ***Data Analysis*** Module. **Auto Scout** data which using for this project, scraped from the on-line car trading company in 2019, contains many features of 9 different car models. In this project, you will have the opportunity to apply many commonly used algorithms for Data Cleaning and Exploratory Data Analysis by using many Python libraries such as Numpy, Pandas, Matplotlib, Seaborn, Scipy you will analyze clean dataset.
#
# **Some Reminders on Exploratory data analysis (EDA)
#
# Exploratory data analysis (EDA) is an especially important activity in the routine of a data analyst or scientist. It enables an in depth understanding of the dataset, define or discard hypotheses and create predictive models on a solid basis. It uses data manipulation techniques and several statistical tools to describe and understand the relationship between variables and how these can impact business. By means of EDA, we can obtain meaningful insights that can impact analysis under the following questions (If a checklist is good enough for pilots to use every flight, it’s good enough for data scientists to use with every dataset).
# 1. What question are you trying to solve (or prove wrong)?
# 2. What kind of data do you have?
# 3. What’s missing from the data?
# 4. Where are the outliers?
# 5. How can you add, change or remove features to get more out of your data?
#
# **``Exploratory data analysis (EDA)``** is often an **iterative brainstorming process** where you pose a question, review the data, and develop further questions to investigate before beginning model development work. The image below shows how the brainstorming phase is connected with that of understanding the variables and how this in turn is connected again with the brainstorming phase.<br>
#
# <img src=https://i.ibb.co/k0MC950/EDA-Process.png width="300" height="100">
#
# [Image Credit: Andrew D.](https://towardsdatascience.com/exploratory-data-analysis-in-python-a-step-by-step-process-d0dfa6bf94ee)
#
# **``In this context, the project consists of 3 parts in general:``**
# * **The first part** is related to 'Data Cleaning'. It deals with Incorrect Headers, Incorrect Format, Anomalies, and Dropping useless columns.
# * **The second part** is related to 'Filling Data', in other words 'Imputation'. It deals with Missing Values. Categorical to numeric transformation is done as well.
# * **The third part** is related to 'Handling Outliers of Data' via Visualization libraries. So, some insights will be extracted.
#
# **``NOTE:``**  However, you are free to create your own style. You do NOT have to stick to the steps above. We, the DA & DV instructors, recommend you study each part separately to create a source notebook for each part title for your further studies.

# %% [markdown]
# ## Filling Data (Imputation)

# %%
#Import python libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import datetime
import plotly
import plotly.express as px
import plotly.graph_objs as go
import plotly.offline as py
from plotly.offline import iplot
from plotly.subplots import make_subplots
import plotly.figure_factory as ff


from pandas.plotting import register_matplotlib_converters
from pylab import rcParams
#from skimpy import clean_columns

import warnings
warnings.filterwarnings("ignore")

plt.rcParams["figure.figsize"] = (12, 8)
pd.set_option('display.max_columns', None)
sns.set_theme(font_scale=1.2, style="darkgrid")
#pd.set_option('display.float_format', lambda x: '%.3' % x)

# %%
# Reading file from json
df_origin = pd.read_csv("AutoScout_Cleaned", index_col=[0])
df = df_origin.copy()
df.head().T
# Out:
#                                                                       0  \
# body_type                                                        Sedans
# price                                                           15770.0
# vat                                                      VAT deductible
# km                                                              56013.0
# registration                                                 2016-01-01
# prev_owner                                                          2.0
# type                                                               Used
# make                                                               Audi
# model                                                                A1
# body_color                                                        Black
# paint_type                                                     Metallic
# nr_of_doors                                                         5.0
# nr_of_seats                                                         5.0
# gearing_type                                                  Automatic
# cylinders                                                           3.0
# weight                                                           1220.0
# drive_chain                                                       front
# fuel                                                             Diesel
# emission_class                                                   Euro 6
# comfort               Air conditioning,Armrest,Automatic climate con...
# entertainment         Bluetooth,Hands-free equipment,On-board comput...
# extras                   Alloy wheels,Catalytic Converter,Voice Control
# safety                ABS,Central door lock,Daytime running lights,D...
# emission_label                                                      4.0
# gears                                                               NaN
# country_version                                                     NaN
# last_service_date                                                   NaN
# consumption_comb                                                    3.8
# consumption_city                                                    4.3
# consumption_country                                                 3.5
# hp_kw                                                              66.0
# Particulate_Filter                                                    1
# inspection_time                                              2021-06-01
# inspection_situation                                                  1
# warranty_month                                                      NaN
# co2_emission_gr                                                    99.0
# upholstery_type                                                   Cloth
# upholstery_color                                                  Black
# engine_size                                                      1422.0
# last_service_time                                                   NaN
#
#                                                                       1  \
# body_type                                                        Sedans
# price                                                           14500.0
# vat                                                    Price negotiable
# km                                                              80000.0
# registration                                                 2017-03-01
# prev_owner                                                          NaN
# type                                                               Used
# make                                                               Audi
# model                                                                A1
# body_color                                                          Red
# paint_type                                                          NaN
# nr_of_doors                                                         3.0
# nr_of_seats                                                         4.0
# gearing_type                                                  Automatic
# cylinders                                                           4.0
# weight                                                           1255.0
# drive_chain                                                       front
# fuel                                                            Benzine
# emission_class                                                   Euro 6
# comfort               Air conditioning,Automatic climate control,Hil...
# entertainment         Bluetooth,Hands-free equipment,On-board comput...
# extras                Alloy wheels,Sport seats,Sport suspension,Voic...
# safety                ABS,Central door lock,Central door lock with r...
# emission_label                                                      4.0
# gears                                                               7.0
# country_version                                                     NaN
# last_service_date                                                   NaN
# consumption_comb                                                    5.6
# consumption_city                                                    7.1
# consumption_country                                                 4.7
# hp_kw                                                             141.0
# Particulate_Filter                                                    0
# inspection_time                                                     NaN
# inspection_situation                                                  0
# warranty_month                                                      NaN
# co2_emission_gr                                                   129.0
# upholstery_type                                                   Cloth
# upholstery_color                                                   Grey
# engine_size                                                      1798.0
# last_service_time                                                   NaN
#
#                                                                       2  \
# body_type                                                        Sedans
# price                                                           14640.0
# vat                                                      VAT deductible
# km                                                              83450.0
# registration                                                 2016-02-01
# prev_owner                                                          1.0
# type                                                               Used
# make                                                               Audi
# model                                                                A1
# body_color                                                        Black
# paint_type                                                     Metallic
# nr_of_doors                                                         4.0
# nr_of_seats                                                         4.0
# gearing_type                                                  Automatic
# cylinders                                                           NaN
# weight                                                              NaN
# drive_chain                                                       front
# fuel                                                             Diesel
# emission_class                                                   Euro 6
# comfort               Air conditioning,Cruise control,Electrical sid...
# entertainment                                     MP3,On-board computer
# extras                                       Alloy wheels,Voice Control
# safety                ABS,Central door lock,Daytime running lights,D...
# emission_label                                                      4.0
# gears                                                               NaN
# country_version                                                     NaN
# last_service_date                                                   NaN
# consumption_comb                                                    3.8
# consumption_city                                                    4.4
# consumption_country                                                 3.4
# hp_kw                                                              85.0
# Particulate_Filter                                                    1
# inspection_time                                                     NaN
# inspection_situation                                                  0
# warranty_month                                                      NaN
# co2_emission_gr                                                    99.0
# upholstery_type                                                   Cloth
# upholstery_color                                                  Black
# engine_size                                                      1598.0
# last_service_time                                                   NaN
#
#                                                                       3  \
# body_type                                                        Sedans
# price                                                           14500.0
# vat                                                                 NaN
# km                                                              73000.0
# registration                                                 2016-08-01
# prev_owner                                                          1.0
# type                                                               Used
# make                                                               Audi
# model                                                                A1
# body_color                                                        Brown
# paint_type                                                     Metallic
# nr_of_doors                                                         3.0
# nr_of_seats                                                         4.0
# gearing_type                                                  Automatic
# cylinders                                                           3.0
# weight                                                           1195.0
# drive_chain                                                         NaN
# fuel                                                             Diesel
# emission_class                                                   Euro 6
# comfort               Air suspension,Armrest,Auxiliary heating,Elect...
# entertainment         Bluetooth,CD player,Hands-free equipment,MP3,O...
# extras                           Alloy wheels,Sport seats,Voice Control
# safety                ABS,Alarm system,Central door lock with remote...
# emission_label                                                      NaN
# gears                                                               6.0
# country_version                                                     NaN
# last_service_date                                                   NaN
# consumption_comb                                                    3.8
# consumption_city                                                    4.3
# consumption_country                                                 3.5
# hp_kw                                                              66.0
# Particulate_Filter                                                    1
# inspection_time                                                     NaN
# inspection_situation                                                  0
# warranty_month                                                      NaN
# co2_emission_gr                                                    99.0
# upholstery_type                                                     NaN
# upholstery_color                                                    NaN
# engine_size                                                      1422.0
# last_service_time                                                   NaN
#
#                                                                       4
# body_type                                                        Sedans
# price                                                           16790.0
# vat                                                                 NaN
# km                                                              16200.0
# registration                                                 2016-05-01
# prev_owner                                                          1.0
# type                                                               Used
# make                                                               Audi
# model                                                                A1
# body_color                                                        Black
# paint_type                                                     Metallic
# nr_of_doors                                                         5.0
# nr_of_seats                                                         5.0
# gearing_type                                                  Automatic
# cylinders                                                           3.0
# weight                                                              NaN
# drive_chain                                                       front
# fuel                                                             Diesel
# emission_class                                                   Euro 6
# comfort               Air conditioning,Armrest,Automatic climate con...
# entertainment         Bluetooth,CD player,Hands-free equipment,MP3,O...
# extras                Alloy wheels,Sport package,Sport suspension,Vo...
# safety                ABS,Central door lock,Driver-side airbag,Elect...
# emission_label                                                      4.0
# gears                                                               NaN
# country_version                                                 Germany
# last_service_date                                                   NaN
# consumption_comb                                                    4.1
# consumption_city                                                    4.6
# consumption_country                                                 3.8
# hp_kw                                                              66.0
# Particulate_Filter                                                    1
# inspection_time                                                     NaN
# inspection_situation                                                  1
# warranty_month                                                      NaN
# co2_emission_gr                                                   109.0
# upholstery_type                                                   Cloth
# upholstery_color                                                  Black
# engine_size                                                      1422.0
# last_service_time                                                   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15919 entries, 0 to 15918
# Data columns (total 40 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   body_type             15860 non-null  object
#  1   price                 15919 non-null  float64
#  2   vat                   11406 non-null  object
#  3   km                    14895 non-null  float64
#  4   registration          14322 non-null  object
#  5   prev_owner            9279 non-null   float64
#  6   type                  15917 non-null  object
#  7   make                  15919 non-null  object
#  8   model                 15919 non-null  object
#  9   body_color            15338 non-null  object
#  10  paint_type            10147 non-null  object
#  11  nr_of_doors           15707 non-null  float64
#  12  nr_of_seats           14942 non-null  float64
#  13  gearing_type          15919 non-null  object
#  14  cylinders             10239 non-null  float64
#  15  weight                8945 non-null   float64
#  16  drive_chain           9061 non-null   object
#  17  fuel                  15919 non-null  object
#  18  emission_class        12999 non-null  object
#  19  comfort               14999 non-null  object
#  20  entertainment         14545 non-null  object
#  21  extras                12957 non-null  object
#  22  safety                14937 non-null  object
#  23  emission_label        7969 non-null   float64
#  24  gears                 11207 non-null  float64
#  25  country_version       7586 non-null   object
#  26  last_service_date     566 non-null    object
#  27  consumption_comb      13886 non-null  float64
#  28  consumption_city      13483 non-null  float64
#  29  consumption_country   13543 non-null  float64
#  30  hp_kw                 15833 non-null  float64
#  31  Particulate_Filter    15919 non-null  int64
#  32  inspection_time       3469 non-null   object
#  33  inspection_situation  15919 non-null  int64
#  34  warranty_month        4853 non-null   float64
#  35  co2_emission_gr       13484 non-null  float64
#  36  upholstery_type       11416 non-null  object
#  37  upholstery_color      10841 non-null  object
#  38  engine_size           15743 non-null  float64
#  39  last_service_time     566 non-null    object
# dtypes: float64(16), int64(2), object(22)
# memory usage: 5.0+ MB
