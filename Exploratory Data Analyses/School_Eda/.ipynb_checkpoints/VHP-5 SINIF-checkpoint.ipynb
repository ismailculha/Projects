# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_1 = pd.read_excel("5SINIF_1.xlsx")

# %%
df_1.head()
# Out:
#    NO  Std_No       Std_Name Std_C         Tur_D_Y_N         Tar_D_Y_N  \
# 0   1     253   ZEYNEP TÜREL    5C  14     1   13,67  10     0   10,00
# 1   2     104   ASUDE YÜKSEL    5B  14     1   13,67  9      1    8,67
# 2   3     360  ALPER ÖZDEMİR    5A  13     2   12,33  8      2    7,33
# 3   4     356       TAHA TAŞ    5A  14     1   13,67  9      1    8,67
# 4   5     367    BEYZA KILIÇ    5B  14     1   13,67  10     0   10,00
#
#           Din_D_Y_N  Ing_D  Ing_Y  Ing_N  ...  Fen_Y  Fen_N  Top_D  Top_Y  \
# 0  9      1    8,67   10.0    0.0  10.00  ...      0  15.00     73      2
# 1  9      1    8,67   10.0    0.0  10.00  ...      1  13.67     71      4
# 2  10     0   10,00    8.0    2.0   7.33  ...      0  15.00     69      6
# 3  10     0   10,00    4.0    3.0   3.00  ...      0  15.00     67      5
# 4  10     0   10,00   10.0    0.0  10.00  ...      0  14.00     71      3
#
#    Top_N      LGS   Der_C_S  Der_Mer  Der_Ama  Der_Gnl
# ...

# %%
df_2 = pd.read_excel("5SINIF_2.xlsx")
df_2.head()
# Out:
#    NO  Std_No            Std_Name Std_C         Tur_D_Y_N         Tar_D_Y_N  \
# 0   1     360       ALPER ÖZDEMİR    5A  11     4    9,67  10     0   10,00
# 1   2     358            TAHA TAŞ    5A  12     3   11,00  9      1    8,67
# 2   3     390   NİL BİLGE İZMİRLİ    5A  11     2   10,33  9      1    8,67
# 3   4     397  MELİK KAAN ÖZÇELİK    5A  10     3    9,00  9      1    8,67
# 4   5     156      ÇINAR GÜNGÖREN    5A  10     5    8,33  10     0   10,00
#
#           Din_D_Y_N  Ing_D  Ing_Y  Ing_N         Mat_D_Y_N         Fen_D_Y_N  \
# 0  9      1    8,67   10.0    0.0  10.00  14     1   13,67  14     1   13,67
# 1  8      2    7,33    9.0    1.0   8.67  15     0   15,00  11     4    9,67
# 2  9      1    8,67   10.0    0.0  10.00  11     1   10,67  14     1   13,67
# 3  10     0   10,00   10.0    0.0  10.00  12     1   11,67  13     2   12,33
# 4  7      1    6,67   10.0    0.0  10.00  11     1   10,67  14     1   13,67
#
# ...

# %%
df_3 = pd.read_excel("5SINIF_3.xlsx")
df_3.head()
# Out:
#    NO  Std_No           Std_Name Std_C         Tur_D_Y_N         Tar_D_Y_N  \
# 0   1     360      ALPER ÖZDEMİR    5A  15     0   15,00  10     0   10,00
# 1   2     253       ZEYNEP TÜREL    5C  13     2   12,33  10     0   10,00
# 2   3     390  NİL BİLGE İZMİRLİ    5A  15     0   15,00  9      1    8,67
# 3   4     170         DURU ŞAHİN    5A  12     3   11,00  10     0   10,00
# 4   5     200     KORAY GACARLAR    5B  15     0   15,00  10     0   10,00
#
#           Din_D_Y_N  Ing_D  Ing_Y  Ing_N  ...  Fen_Y  Fen_N  Top_D  Top_Y  \
# 0  10     0   10,00     10      0   10.0  ...      0  15.00     73      2
# 1  10     0   10,00     10      0   10.0  ...      0  15.00     71      4
# 2  10     0   10,00     10      0   10.0  ...      0  15.00     69      4
# 3  9      1    8,67     10      0   10.0  ...      1  13.67     67      8
# 4  10     0   10,00     10      0   10.0  ...      2  10.33     67      4
#
#    Top_N      LGS   Der_C_S  Der_Mer  Der_Ama       Der_Gnl
# ...

# %%
df_4 = pd.read_excel("5SINIF_4.xlsx")
df_4.head()
# Out:
#    NO  Std_No           Std_Name Std_C         Tur_D_Y_N         Tar_D_Y_N  \
# 0   1     253       ZEYNEP TÜREL    5C  13     2   12,33  10     0   10,00
# 1   2     360      ALPER ÖZDEMİR    5A  13     2   12,33  9      1    8,67
# 2   3     367        BEYZA KILIÇ    5B  12     3   11,00  8      2    7,33
# 3   4     200     KORAY GACARLAR    5B  10     5    8,33  9      1    8,67
# 4   5     390  NİL BİLGE İZMİRLİ    5A  10     4    8,67  10     0   10,00
#
#           Din_D_Y_N  Ing_D  Ing_Y  Ing_N  ...         Fen_D_Y_N Top_D  Top_Y  \
# 0  10     0   10,00      9      0   9.00  ...  13     2   12,33    68      5
# 1  8      2    7,33     10      0  10.00  ...  13     2   12,33    66      9
# 2  9      1    8,67      9      1   8.67  ...  13     1   12,67    64      9
# 3  6      3    5,00     10      0  10.00  ...  12     3   11,00    62     12
# 4  10     0   10,00      6      4   4.67  ...  13     2   12,33    62     10
#
# ...

# %%
df_5 = pd.read_excel("5SINIF_5.xlsx")
df_5.head()
# Out:
#    NO  Std_No        Std_Name Std_C         Tur_D_Y_N         Tar_D_Y_N  \
# 0   1     360   ALPER ÖZDEMİR    5A  13     2   12,33  9      1    8,67
# 1   2     104    ASUDE YÜKSEL    5B  14     1   13,67  9      1    8,67
# 2   3     358        TAHA TAŞ    5A  13     1   12,67  8      2    7,33
# 3   4     200  KORAY GACARLAR    5B  13     1   12,67  7      3    6,00
# 4   5     367     BEYZA KILIÇ    5B  14     1   13,67  8      2    7,33
#
#           Din_D_Y_N  Ing_D  Ing_Y  Ing_N         Mat_D_Y_N         Fen_D_Y_N  \
# 0  10     0   10,00   10.0    0.0  10.00  12     3   11,00  13     2   12,33
# 1  9      1    8,67   10.0    0.0  10.00  12     3   11,00  11     4    9,67
# 2  6      0    6,00    NaN    NaN    NaN  13     2   12,33  14     1   13,67
# 3  9      1    8,67    9.0    1.0   8.67  9      3    8,00  14     1   13,67
# 4  8      2    7,33   10.0    0.0  10.00  10     4    8,67  12     3   11,00
#
# ...

# %%
df_1["SINAV"] = "Argon_CDS"

# %%
df_1.head()
# Out:
#    NO  Std_No       Std_Name Std_C         Tur_D_Y_N         Tar_D_Y_N  \
# 0   1     253   ZEYNEP TÜREL    5C  14     1   13,67  10     0   10,00
# 1   2     104   ASUDE YÜKSEL    5B  14     1   13,67  9      1    8,67
# 2   3     360  ALPER ÖZDEMİR    5A  13     2   12,33  8      2    7,33
# 3   4     356       TAHA TAŞ    5A  14     1   13,67  9      1    8,67
# 4   5     367    BEYZA KILIÇ    5B  14     1   13,67  10     0   10,00
#
#           Din_D_Y_N  Ing_D  Ing_Y  Ing_N  ...  Fen_N  Top_D  Top_Y  Top_N  \
# 0  9      1    8,67   10.0    0.0  10.00  ...  15.00     73      2  72.34
# 1  9      1    8,67   10.0    0.0  10.00  ...  13.67     71      4  69.68
# 2  10     0   10,00    8.0    2.0   7.33  ...  15.00     69      6  66.99
# 3  10     0   10,00    4.0    3.0   3.00  ...  15.00     67      5  65.34
# 4  10     0   10,00   10.0    0.0  10.00  ...  14.00     71      3  70.00
#
#        LGS   Der_C_S  Der_Mer  Der_Ama  Der_Gnl      SINAV
# ...

# %%
df_2["SINAV"] = "Mozaik_1"

# %%
df_3["SINAV"] = "Zeka"

# %%
df_4["SINAV"] = "Mozaik_2"

# %%
df_5["SINAV"] = "Mozaik_3"

# %%
df_4.drop(columns='Unnamed: 19',inplace=True)

# %%
df_1.shape,df_2.shape,df_3.shape,df_4.shape,df_5.shape
# Out:
# ((125, 25), (73, 21), (77, 25), (73, 21), (54, 21))

# %%
display(df_1.head(),df_3.head())
# Out:
#    NO  Std_No       Std_Name Std_C         Tur_D_Y_N         Tar_D_Y_N  \
# 0   1     253   ZEYNEP TÜREL    5C  14     1   13,67  10     0   10,00
# 1   2     104   ASUDE YÜKSEL    5B  14     1   13,67  9      1    8,67
# 2   3     360  ALPER ÖZDEMİR    5A  13     2   12,33  8      2    7,33
# 3   4     356       TAHA TAŞ    5A  14     1   13,67  9      1    8,67
# 4   5     367    BEYZA KILIÇ    5B  14     1   13,67  10     0   10,00
#
#           Din_D_Y_N  Ing_D  Ing_Y  Ing_N  ...  Fen_N  Top_D  Top_Y  Top_N  \
# 0  9      1    8,67   10.0    0.0  10.00  ...  15.00     73      2  72.34
# 1  9      1    8,67   10.0    0.0  10.00  ...  13.67     71      4  69.68
# 2  10     0   10,00    8.0    2.0   7.33  ...  15.00     69      6  66.99
# 3  10     0   10,00    4.0    3.0   3.00  ...  15.00     67      5  65.34
# 4  10     0   10,00   10.0    0.0  10.00  ...  14.00     71      3  70.00
#
#        LGS   Der_C_S  Der_Mer  Der_Ama  Der_Gnl      SINAV
# ...

# %%
df=pd.concat([df_1,df_3])

# %%
pd.concat([df_2,df_5]).iloc[70:80]
# Out:
#     NO  Std_No             Std_Name Std_C         Tur_D_Y_N         Tar_D_Y_N  \
# 70  71     524      POYRAZ K IRIMLI    5C               NaN  4      6    2,00
# 71  72     265        ASEL KARAKAYA    5B               NaN   0     10  -3,33
# 72  73     332    MUHA MET EMİN KAY    5C               NaN  1      9   -2,00
# 0    1     360        ALPER ÖZDEMİR    5A  13     2   12,33  9      1    8,67
# 1    2     104         ASUDE YÜKSEL    5B  14     1   13,67  9      1    8,67
# 2    3     358             TAHA TAŞ    5A  13     1   12,67  8      2    7,33
# 3    4     200       KORAY GACARLAR    5B  13     1   12,67  7      3    6,00
# 4    5     367          BEYZA KILIÇ    5B  14     1   13,67  8      2    7,33
# 5    6     409  ÖMER HALİL YILDIRIM    5D  10     4    8,67  8      2    7,33
# 6    7     498    ZELİHA CEBECİOĞLU    5B  14     1   13,67  8      2    7,33
#
#            Din_D_Y_N  Ing_D  Ing_Y  Ing_N  ...         Fen_D_Y_N Top_D  Top_Y  \
# ...

# %%
df.head(50)
# Out:
#     NO  Std_No             Std_Name Std_C         Tur_D_Y_N         Tar_D_Y_N  \
# 0    1     253         ZEYNEP TÜREL    5C  14     1   13,67  10     0   10,00
# 1    2     104         ASUDE YÜKSEL    5B  14     1   13,67  9      1    8,67
# 2    3     360        ALPER ÖZDEMİR    5A  13     2   12,33  8      2    7,33
# 3    4     356             TAHA TAŞ    5A  14     1   13,67  9      1    8,67
# 4    5     367          BEYZA KILIÇ    5B  14     1   13,67  10     0   10,00
# 5    6     200       KORAY GACARLAR    5B  12     3   11,00  9      1    8,67
# 6    7     390    NİL BİLGE İZMİRLİ    5A  15     0   15,00  9      1    8,67
# 7    8     397   MELİK KAAN ÖZÇELİK    5A  12     3   11,00  8      2    7,33
# 8    9      78    ÇAĞAN IŞIK AKSOĞA    5B  11     4    9,67  8      2    7,33
# 9   10     170           DURU ŞAHİN    5A  12     2   11,33  9      1    8,67
# 10  11     409  ÖMER HALİL YILDIRIM    5D  12     3   11,00  9      1    8,67
# ...

# %%
df[["Tur_D","Tur_Y","Tur_N"]] = ex
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10424/2552974277.py in <module>
# ----> 1 df[["Tur_D","Tur_Y","Tur_N"]] = ex
#
# NameError: name 'ex' is not defined

# %%
ex_Tur = df["Tur_D_Y_N"].str.extract("(\d+)\s+(\d\d?)\s+(.*)")

# %%
df.head().iloc[:,10:]
# Out:
#    Mat_D  Mat_Y  Mat_N  Fen_D  Fen_Y  Fen_N  Top_D  Top_Y  Top_N      LGS  \
# 0     15      0  15.00     15      0  15.00     73      2  72.34  488.641
# 1     15      0  15.00     14      1  13.67     71      4  69.68  476.061
# 2     15      0  15.00     15      0  15.00     69      6  66.99  469.712
# 3     15      0  15.00     15      0  15.00     67      5  65.34  469.488
# 4     13      2  12.33     14      0  14.00     71      3  70.00  462.012
#
#     Der_C_S  Der_Mer  Der_Ama Der_Gnl      SINAV Tur_D Tur_Y  Tur_N
# 0  1      1        1        1       1  Argon_CDS    14     1  13,67
# 1  1      2        2        2       6  Argon_CDS    14     1  13,67
# 2  1      3        3        3      12  Argon_CDS    13     2  12,33
# 3  2      4        4        4      13  Argon_CDS    14     1  13,67
# 4  2      5        5        5      25  Argon_CDS    14     1  13,67

# %%
ex_Tur = df["Tur_D_Y_N"].str.extract("(\d+)\s+(\d\d?)\s+(.*)")
ex_Tar = df["Tar_D_Y_N"].str.extract("(\d+)\s+(\d\d?)\s+(.*)")
ex_Din = df["Din_D_Y_N"].str.extract("(\d+)\s+(\d\d?)\s+(.*)")

# %%
df[["Tur_D","Tur_Y","Tur_N"]] = ex_Tur
df[["Tar_D","Tar_Y","Tar_N"]] = ex_Tar
df[["Din_D","Din_Y","Din_N"]] = ex_Din
df.head()
# Out:
#    NO  Std_No       Std_Name Std_C         Tur_D_Y_N         Tar_D_Y_N  \
# 0   1     253   ZEYNEP TÜREL    5C  14     1   13,67  10     0   10,00
# 1   2     104   ASUDE YÜKSEL    5B  14     1   13,67  9      1    8,67
# 2   3     360  ALPER ÖZDEMİR    5A  13     2   12,33  8      2    7,33
# 3   4     356       TAHA TAŞ    5A  14     1   13,67  9      1    8,67
# 4   5     367    BEYZA KILIÇ    5B  14     1   13,67  10     0   10,00
#
#           Din_D_Y_N  Ing_D  Ing_Y  Ing_N  ...      SINAV  Tur_D  Tur_Y  Tur_N  \
# 0  9      1    8,67   10.0    0.0  10.00  ...  Argon_CDS     14      1  13,67
# 1  9      1    8,67   10.0    0.0  10.00  ...  Argon_CDS     14      1  13,67
# 2  10     0   10,00    8.0    2.0   7.33  ...  Argon_CDS     13      2  12,33
# 3  10     0   10,00    4.0    3.0   3.00  ...  Argon_CDS     14      1  13,67
# 4  10     0   10,00   10.0    0.0  10.00  ...  Argon_CDS     14      1  13,67
#
#    Tar_D  Tar_Y  Tar_N  Din_D  Din_Y  Din_N
# ...

# %%
df.drop(columns=["Tur_D_Y_N","Tar_D_Y_N","Din_D_Y_N"], inplace=True)
df.head()
# Out:
#    NO  Std_No       Std_Name Std_C  Ing_D  Ing_Y  Ing_N  Mat_D  Mat_Y  Mat_N  \
# 0   1     253   ZEYNEP TÜREL    5C   10.0    0.0  10.00     15      0  15.00
# 1   2     104   ASUDE YÜKSEL    5B   10.0    0.0  10.00     15      0  15.00
# 2   3     360  ALPER ÖZDEMİR    5A    8.0    2.0   7.33     15      0  15.00
# 3   4     356       TAHA TAŞ    5A    4.0    3.0   3.00     15      0  15.00
# 4   5     367    BEYZA KILIÇ    5B   10.0    0.0  10.00     13      2  12.33
#
#    ...      SINAV  Tur_D  Tur_Y  Tur_N  Tar_D  Tar_Y  Tar_N Din_D  Din_Y  \
# 0  ...  Argon_CDS     14      1  13,67     10      0  10,00     9      1
# 1  ...  Argon_CDS     14      1  13,67      9      1   8,67     9      1
# 2  ...  Argon_CDS     13      2  12,33      8      2   7,33    10      0
# 3  ...  Argon_CDS     14      1  13,67      9      1   8,67    10      0
# 4  ...  Argon_CDS     14      1  13,67     10      0  10,00    10      0
#
#    Din_N
# 0   8,67
# 1   8,67
# 2  10,00
# 3  10,00
# 4  10,00
# ...

# %%
df.columns
# Out:
# Index(['NO', 'Std_No', 'Std_Name', 'Std_C', 'Ing_D', 'Ing_Y', 'Ing_N', 'Mat_D',
#        'Mat_Y', 'Mat_N', 'Fen_D', 'Fen_Y', 'Fen_N', 'Top_D', 'Top_Y', 'Top_N',
#        'LGS', 'Der_C_S', 'Der_Mer', 'Der_Ama', 'Der_Gnl', 'SINAV', 'Tur_D',
#        'Tur_Y', 'Tur_N', 'Tar_D', 'Tar_Y', 'Tar_N', 'Din_D', 'Din_Y', 'Din_N'],
#       dtype='object')

# %%
df[["Der_C","Der_S"]] =df["Der_C_S"].str.extract("(\d+)\s+(\d+)")
df.drop(columns=["Der_C_S"], inplace=True)

# %%
df.head()
# Out:
#    NO  Std_No       Std_Name Std_C  Ing_D  Ing_Y  Ing_N  Mat_D  Mat_Y  Mat_N  \
# 0   1     253   ZEYNEP TÜREL    5C   10.0    0.0  10.00     15      0  15.00
# 1   2     104   ASUDE YÜKSEL    5B   10.0    0.0  10.00     15      0  15.00
# 2   3     360  ALPER ÖZDEMİR    5A    8.0    2.0   7.33     15      0  15.00
# 3   4     356       TAHA TAŞ    5A    4.0    3.0   3.00     15      0  15.00
# 4   5     367    BEYZA KILIÇ    5B   10.0    0.0  10.00     13      2  12.33
#
#    ...  Tur_Y  Tur_N  Tar_D  Tar_Y  Tar_N  Din_D  Din_Y  Din_N  Der_C Der_S
# 0  ...      1  13,67     10      0  10,00      9      1   8,67      1     1
# 1  ...      1  13,67      9      1   8,67      9      1   8,67      1     2
# 2  ...      2  12,33      8      2   7,33     10      0  10,00      1     3
# 3  ...      1  13,67      9      1   8,67     10      0  10,00      2     4
# 4  ...      1  13,67     10      0  10,00     10      0  10,00      2     5
#
# [5 rows x 32 columns]

# %%
df_n = pd.concat([df_2,df_5,df_4])
df_n.columns
# Out:
# Index(['NO', 'Std_No', 'Std_Name', 'Std_C', 'Tur_D_Y_N', 'Tar_D_Y_N',
#        'Din_D_Y_N', 'Ing_D', 'Ing_Y', 'Ing_N', 'Mat_D_Y_N', 'Fen_D_Y_N',
#        'Top_D', 'Top_Y', 'Top_N', 'LGS', 'Der_C_S', 'Der_Mer', 'Der_Ama',
#        'Der_Gnl', 'SINAV'],
#       dtype='object')

# %%
ex_Tur = df_n["Tur_D_Y_N"].str.extract("(\d+)\s+(\d\d?)\s+(.*)")
ex_Tar = df_n["Tar_D_Y_N"].str.extract("(\d+)\s+(\d\d?)\s+(.*)")
ex_Din = df_n["Din_D_Y_N"].str.extract("(\d+)\s+(\d\d?)\s+(.*)")
ex_Mat = df_n["Mat_D_Y_N"].str.extract("(\d+)\s+(\d\d?)\s+(.*)")
ex_Fen = df_n["Fen_D_Y_N"].str.extract("(\d+)\s+(\d\d?)\s+(.*)")
df_n[["Der_C","Der_S"]] = df_n["Der_C_S"].str.extract("(\d+)\s+(\d+)")

# %%
df_n[["Tur_D","Tur_Y","Tur_N"]] = ex_Tur
df_n[["Tar_D","Tar_Y","Tar_N"]] = ex_Tar
df_n[["Din_D","Din_Y","Din_N"]] = ex_Din
df_n[["Mat_D","Mat_Y","Mat_N"]] = ex_Mat
df_n[["Fen_D","Fen_Y","Fen_N"]] = ex_Fen

df_n.head()
# Out:
#    NO  Std_No            Std_Name Std_C         Tur_D_Y_N         Tar_D_Y_N  \
# 0   1     360       ALPER ÖZDEMİR    5A  11     4    9,67  10     0   10,00
# 1   2     358            TAHA TAŞ    5A  12     3   11,00  9      1    8,67
# 2   3     390   NİL BİLGE İZMİRLİ    5A  11     2   10,33  9      1    8,67
# 3   4     397  MELİK KAAN ÖZÇELİK    5A  10     3    9,00  9      1    8,67
# 4   5     156      ÇINAR GÜNGÖREN    5A  10     5    8,33  10     0   10,00
#
#           Din_D_Y_N  Ing_D  Ing_Y  Ing_N  ...  Tar_N Din_D  Din_Y  Din_N  \
# 0  9      1    8,67   10.0    0.0  10.00  ...  10,00     9      1   8,67
# 1  8      2    7,33    9.0    1.0   8.67  ...   8,67     8      2   7,33
# 2  9      1    8,67   10.0    0.0  10.00  ...   8,67     9      1   8,67
# 3  10     0   10,00   10.0    0.0  10.00  ...   8,67    10      0  10,00
# 4  7      1    6,67   10.0    0.0  10.00  ...  10,00     7      1   6,67
#
#    Mat_D  Mat_Y  Mat_N  Fen_D  Fen_Y  Fen_N
# ...

# %%
df_n.drop(columns=["Tur_D_Y_N","Tar_D_Y_N","Din_D_Y_N","Mat_D_Y_N","Fen_D_Y_N","Der_C_S"], inplace=True)
df_n.head()
# Out:
#    NO  Std_No            Std_Name Std_C  Ing_D  Ing_Y  Ing_N  Top_D  Top_Y  \
# 0   1     360       ALPER ÖZDEMİR    5A   10.0    0.0  10.00     68      7
# 1   2     358            TAHA TAŞ    5A    9.0    1.0   8.67     64     11
# 2   3     390   NİL BİLGE İZMİRLİ    5A   10.0    0.0  10.00     64      6
# 3   4     397  MELİK KAAN ÖZÇELİK    5A   10.0    0.0  10.00     64      7
# 4   5     156      ÇINAR GÜNGÖREN    5A   10.0    0.0  10.00     62      8
#
#    Top_N  ...  Tar_N  Din_D  Din_Y  Din_N Mat_D Mat_Y  Mat_N Fen_D Fen_Y  \
# 0  65.68  ...  10,00      9      1   8,67    14     1  13,67    14     1
# 1  60.34  ...   8,67      8      2   7,33    15     0  15,00    11     4
# 2  62.01  ...   8,67      9      1   8,67    11     1  10,67    14     1
# 3  61.67  ...   8,67     10      0  10,00    12     1  11,67    13     2
# 4  59.34  ...  10,00      7      1   6,67    11     1  10,67    14     1
#
#    Fen_N
# 0  13,67
# 1   9,67
# 2  13,67
# 3  12,33
# 4  13,67
#
# ...

# %%
df_n.shape,df.shape
# Out:
# ((200, 32), (202, 32))

# %%
df = pd.concat([df,df_n])

# %% [markdown]
# # 1. Data Anlama

# %%
df.head()
# Out:
#    NO  Std_No       Std_Name Std_C  Ing_D  Ing_Y  Ing_N Mat_D Mat_Y  Mat_N  \
# 0   1     253   ZEYNEP TÜREL    5C   10.0    0.0  10.00    15     0   15.0
# 1   2     104   ASUDE YÜKSEL    5B   10.0    0.0  10.00    15     0   15.0
# 2   3     360  ALPER ÖZDEMİR    5A    8.0    2.0   7.33    15     0   15.0
# 3   4     356       TAHA TAŞ    5A    4.0    3.0   3.00    15     0   15.0
# 4   5     367    BEYZA KILIÇ    5B   10.0    0.0  10.00    13     2  12.33
#
#    ... Tur_Y  Tur_N Tar_D  Tar_Y  Tar_N  Din_D  Din_Y  Din_N  Der_C Der_S
# 0  ...     1  13,67    10      0  10,00      9      1   8,67      1     1
# 1  ...     1  13,67     9      1   8,67      9      1   8,67      1     2
# 2  ...     2  12,33     8      2   7,33     10      0  10,00      1     3
# 3  ...     1  13,67     9      1   8,67     10      0  10,00      2     4
# 4  ...     1  13,67    10      0  10,00     10      0  10,00      2     5
#
# [5 rows x 32 columns]

# %%
df.columns
# Out:
# Index(['NO', 'Std_No', 'Std_Name', 'Std_C', 'Ing_D', 'Ing_Y', 'Ing_N', 'Mat_D',
#        'Mat_Y', 'Mat_N', 'Fen_D', 'Fen_Y', 'Fen_N', 'Top_D', 'Top_Y', 'Top_N',
#        'LGS', 'Der_Mer', 'Der_Ama', 'Der_Gnl', 'SINAV', 'Tur_D', 'Tur_Y',
#        'Tur_N', 'Tar_D', 'Tar_Y', 'Tar_N', 'Din_D', 'Din_Y', 'Din_N', 'Der_C',
#        'Der_S'],
#       dtype='object')

# %%
df = df[['NO','Std_No', 'Std_Name', 'Std_C', 'SINAV', 'LGS',
         'Tur_D', 'Tur_Y', 'Tur_N', 'Din_D','Din_Y', 'Din_N', 'Tar_D', 'Tar_Y', 'Tar_N',
         'Ing_D',  'Ing_Y','Ing_N','Mat_D',  'Mat_Y','Mat_N', 'Fen_D',  'Fen_Y','Fen_N', 'Top_D',  'Top_Y','Top_N',
         'Der_C','Der_S','Der_Mer','Der_Ama','Der_Gnl' ]]

# %%
df.head()
# Out:
#    NO  Std_No       Std_Name Std_C      SINAV      LGS Tur_D Tur_Y  Tur_N  \
# 0   1     253   ZEYNEP TÜREL    5C  Argon_CDS  488.641    14     1  13,67
# 1   2     104   ASUDE YÜKSEL    5B  Argon_CDS  476.061    14     1  13,67
# 2   3     360  ALPER ÖZDEMİR    5A  Argon_CDS  469.712    13     2  12,33
# 3   4     356       TAHA TAŞ    5A  Argon_CDS  469.488    14     1  13,67
# 4   5     367    BEYZA KILIÇ    5B  Argon_CDS  462.012    14     1  13,67
#
#   Din_D  ... Fen_Y  Fen_N Top_D Top_Y  Top_N  Der_C  Der_S  Der_Mer Der_Ama  \
# 0     9  ...     0   15.0    73     2  72.34      1      1        1       1
# 1     9  ...     1  13.67    71     4  69.68      1      2        2       2
# 2    10  ...     0   15.0    69     6  66.99      1      3        3       3
# 3    10  ...     0   15.0    67     5  65.34      2      4        4       4
# 4    10  ...     0   14.0    71     3  70.00      2      5        5       5
#
#   Der_Gnl
# 0       1
# 1       6
# 2      12
# 3      13
# ...

# %%
df.shape
# Out:
# (402, 32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 402 entries, 0 to 72
# Data columns (total 32 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   NO        402 non-null    int64
#  1   Std_No    402 non-null    int64
#  2   Std_Name  402 non-null    object
#  3   Std_C     402 non-null    object
#  4   SINAV     402 non-null    object
#  5   LGS       402 non-null    float64
#  6   Tur_D     395 non-null    object
#  7   Tur_Y     395 non-null    object
#  8   Tur_N     395 non-null    object
#  9   Din_D     399 non-null    object
#  10  Din_Y     399 non-null    object
#  11  Din_N     399 non-null    object
#  12  Tar_D     401 non-null    object
#  13  Tar_Y     401 non-null    object
#  14  Tar_N     401 non-null    object
#  15  Ing_D     399 non-null    float64
#  16  Ing_Y     399 non-null    float64
#  17  Ing_N     399 non-null    float64
#  18  Mat_D     401 non-null    object
#  19  Mat_Y     401 non-null    object
# ...

# %%
 df[["Tur_D", 'Tur_Y', 'Din_D',
       'Din_Y', "Tar_D", 'Tar_Y', 'Mat_D', 'Mat_Y','Ing_D', 'Ing_Y',
       'Fen_D', 'Fen_Y']] = df[["Tur_D", 'Tur_Y', 'Din_D',
       'Din_Y', "Tar_D", 'Tar_Y', 'Mat_D', 'Mat_Y','Ing_D', 'Ing_Y',
       'Fen_D', 'Fen_Y']].astype(dtype=float)

# %% [markdown]
# Burada type ları değiştirerek dataframei normale döndürüyoruz

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.replace(",",".")
# Out:
#      NO  Std_No       Std_Name Std_C      SINAV      LGS  Tur_D  Tur_Y  Tur_N  \
# 0     1     253   ZEYNEP TÜREL    5C  Argon_CDS  488.641   14.0    1.0  13,67
# 1     2     104   ASUDE YÜKSEL    5B  Argon_CDS  476.061   14.0    1.0  13,67
# 2     3     360  ALPER ÖZDEMİR    5A  Argon_CDS  469.712   13.0    2.0  12,33
# 3     4     356       TAHA TAŞ    5A  Argon_CDS  469.488   14.0    1.0  13,67
# 4     5     367    BEYZA KILIÇ    5B  Argon_CDS  462.012   14.0    1.0  13,67
# ..   ..     ...            ...   ...        ...      ...    ...    ...    ...
# 397  69     111  UĞURCAN GÜPÜR    5B   Mozaik_2  156.113    5.0   10.0   1,67
# 398  70     265  ASEL KARAKAYA    5B   Mozaik_2  147.573    6.0    9.0   3,00
# 399  71     103   EYMEN ERTÜRK    5B   Mozaik_2  131.393    2.0   13.0  -2,33
# 400  72     990     BORAN EKİM    5B   Mozaik_2  116.080    6.0    9.0   3,00
# 401  73      86  *****ON  ONUR    5C   Mozaik_2   93.980    2.0    7.0  -0,33
#
# ...

# %%
for i in df.select_dtypes(include=object).columns:
    df[i] = df[i].replace(",",".")
df
# Out:
#      NO  Std_No       Std_Name Std_C      SINAV      LGS  Tur_D  Tur_Y  Tur_N  \
# 0     1     253   ZEYNEP TÜREL    5C  Argon_CDS  488.641   14.0    1.0  13,67
# 1     2     104   ASUDE YÜKSEL    5B  Argon_CDS  476.061   14.0    1.0  13,67
# 2     3     360  ALPER ÖZDEMİR    5A  Argon_CDS  469.712   13.0    2.0  12,33
# 3     4     356       TAHA TAŞ    5A  Argon_CDS  469.488   14.0    1.0  13,67
# 4     5     367    BEYZA KILIÇ    5B  Argon_CDS  462.012   14.0    1.0  13,67
# ..   ..     ...            ...   ...        ...      ...    ...    ...    ...
# 397  69     111  UĞURCAN GÜPÜR    5B   Mozaik_2  156.113    5.0   10.0   1,67
# 398  70     265  ASEL KARAKAYA    5B   Mozaik_2  147.573    6.0    9.0   3,00
# 399  71     103   EYMEN ERTÜRK    5B   Mozaik_2  131.393    2.0   13.0  -2,33
# 400  72     990     BORAN EKİM    5B   Mozaik_2  116.080    6.0    9.0   3,00
# 401  73      86  *****ON  ONUR    5C   Mozaik_2   93.980    2.0    7.0  -0,33
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 402 entries, 0 to 401
# Data columns (total 32 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   NO        402 non-null    int64
#  1   Std_No    402 non-null    int64
#  2   Std_Name  402 non-null    object
#  3   Std_C     402 non-null    object
#  4   SINAV     402 non-null    object
#  5   LGS       402 non-null    float64
#  6   Tur_D     395 non-null    float64
#  7   Tur_Y     395 non-null    float64
#  8   Tur_N     395 non-null    object
#  9   Din_D     399 non-null    float64
#  10  Din_Y     399 non-null    float64
#  11  Din_N     399 non-null    object
#  12  Tar_D     401 non-null    float64
#  13  Tar_Y     401 non-null    float64
#  14  Tar_N     401 non-null    object
#  15  Ing_D     399 non-null    float64
#  16  Ing_Y     399 non-null    float64
#  17  Ing_N     399 non-null    float64
#  18  Mat_D     401 non-null    float64
#  19  Mat_Y     401 non-null    float64
# ...

# %%
for i in df.select_dtypes(include=object).columns:
    df[i] = df[i].transform(lambda x: str(x).replace(",",".") if "," in str(x) else str(x))

# %%
df.head()
# Out:
#    NO  Std_No       Std_Name Std_C      SINAV      LGS  Tur_D  Tur_Y  Tur_N  \
# 0   1     253   ZEYNEP TÜREL    5C  Argon_CDS  488.641   14.0    1.0  13.67
# 1   2     104   ASUDE YÜKSEL    5B  Argon_CDS  476.061   14.0    1.0  13.67
# 2   3     360  ALPER ÖZDEMİR    5A  Argon_CDS  469.712   13.0    2.0  12.33
# 3   4     356       TAHA TAŞ    5A  Argon_CDS  469.488   14.0    1.0  13.67
# 4   5     367    BEYZA KILIÇ    5B  Argon_CDS  462.012   14.0    1.0  13.67
#
#    Din_D  ...  Fen_Y  Fen_N  Top_D  Top_Y  Top_N  Der_C  Der_S  Der_Mer  \
# 0    9.0  ...    0.0   15.0     73      2  72.34      1      1        1
# 1    9.0  ...    1.0  13.67     71      4  69.68      1      2        2
# 2   10.0  ...    0.0   15.0     69      6  66.99      1      3        3
# 3   10.0  ...    0.0   15.0     67      5  65.34      2      4        4
# 4   10.0  ...    0.0   14.0     71      3  70.00      2      5        5
#
#    Der_Ama  Der_Gnl
# 0        1        1
# 1        2        6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 402 entries, 0 to 401
# Data columns (total 32 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   NO        402 non-null    int64
#  1   Std_No    402 non-null    int64
#  2   Std_Name  402 non-null    object
#  3   Std_C     402 non-null    object
#  4   SINAV     402 non-null    object
#  5   LGS       402 non-null    float64
#  6   Tur_D     395 non-null    float64
#  7   Tur_Y     395 non-null    float64
#  8   Tur_N     402 non-null    object
#  9   Din_D     399 non-null    float64
#  10  Din_Y     399 non-null    float64
#  11  Din_N     402 non-null    object
#  12  Tar_D     401 non-null    float64
#  13  Tar_Y     401 non-null    float64
#  14  Tar_N     402 non-null    object
#  15  Ing_D     399 non-null    float64
#  16  Ing_Y     399 non-null    float64
#  17  Ing_N     399 non-null    float64
#  18  Mat_D     401 non-null    float64
#  19  Mat_Y     401 non-null    float64
# ...

# %%
df.iloc[:,5:-1] = df.iloc[:,5:-1].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 402 entries, 0 to 401
# Data columns (total 32 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   NO        402 non-null    int64
#  1   Std_No    402 non-null    int64
#  2   Std_Name  402 non-null    object
#  3   Std_C     402 non-null    object
#  4   SINAV     402 non-null    object
#  5   LGS       402 non-null    float64
#  6   Tur_D     395 non-null    float64
#  7   Tur_Y     395 non-null    float64
#  8   Tur_N     395 non-null    float64
#  9   Din_D     399 non-null    float64
#  10  Din_Y     399 non-null    float64
#  11  Din_N     399 non-null    float64
#  12  Tar_D     401 non-null    float64
#  13  Tar_Y     401 non-null    float64
#  14  Tar_N     401 non-null    float64
#  15  Ing_D     399 non-null    float64
#  16  Ing_Y     399 non-null    float64
#  17  Ing_N     399 non-null    float64
#  18  Mat_D     401 non-null    float64
# ...

# %%
df.iloc[:,-1]
# Out:
# 0        1
# 1        6
# 2       12
# 3       13
# 4       25
#       ...
# 397    nan
# 398    nan
# 399    nan
# 400    nan
# 401    nan
# Name: Der_Gnl, Length: 402, dtype: object

# %%
df.isnull().sum()
# Out:
# NO          0
# Std_No      0
# Std_Name    0
# Std_C       0
# SINAV       0
# LGS         0
# Tur_D       7
# Tur_Y       7
# Tur_N       7
# Din_D       3
# Din_Y       3
# Din_N       3
# Tar_D       1
# Tar_Y       1
# Tar_N       1
# Ing_D       3
# Ing_Y       3
# Ing_N       3
# Mat_D       1
# Mat_Y       1
# Mat_N       1
# Fen_D       2
# Fen_Y       2
# Fen_N       2
# Top_D       0
# Top_Y       0
# Top_N       0
# Der_C       0
# Der_S       0
# Der_Mer     0
# Der_Ama     0
# Der_Gnl     0
# dtype: int64

# %%
# df.iloc[:,-1] = df.iloc[:,-1].replace("nan",np.nan).astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24280/2475855611.py in <module>
# ----> 1 df.iloc[:,-1] = df.iloc[:,-1].replace("nan",np.nan).astype(float)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ...

# %%
df.iloc[:,-1] = df.iloc[:,-1].str.extract("(\d+)")

# %%
df.groupby("SINAV").head(2)
# Out:
#      NO  Std_No       Std_Name Std_C      SINAV      LGS  Tur_D  Tur_Y  Tur_N  \
# 0     1     253   ZEYNEP TÜREL    5C  Argon_CDS  488.641   14.0    1.0  13.67
# 1     2     104   ASUDE YÜKSEL    5B  Argon_CDS  476.061   14.0    1.0  13.67
# 125   1     360  ALPER ÖZDEMİR    5A       Zeka  480.293   15.0    0.0  15.00
# 126   2     253   ZEYNEP TÜREL    5C       Zeka  463.360   13.0    2.0  12.33
# 202   1     360  ALPER ÖZDEMİR    5A   Mozaik_1  443.880   11.0    4.0   9.67
# 203   2     358       TAHA TAŞ    5A   Mozaik_1  424.093   12.0    3.0  11.00
# 275   1     360  ALPER ÖZDEMİR    5A   Mozaik_3  431.413   13.0    2.0  12.33
# 276   2     104   ASUDE YÜKSEL    5B   Mozaik_3  417.960   14.0    1.0  13.67
# 329   1     253   ZEYNEP TÜREL    5C   Mozaik_2  444.073   13.0    2.0  12.33
# 330   2     360  ALPER ÖZDEMİR    5A   Mozaik_2  435.507   13.0    2.0  12.33
#
#      Din_D  ...  Fen_Y  Fen_N  Top_D  Top_Y  Top_N  Der_C  Der_S  Der_Mer  \
# ...

# %%
df["TotaL"]=df["SINAV"].transform(lambda x: 1970 if x == "Argon_CDS" else (72784 if x == "Mozaik_1" else (103126 if x == "Zeka" else (32439 if x == "Mozaik_2" else 9826))))

# %%
df.groupby("SINAV").head(5)
# Out:
#      NO  Std_No            Std_Name Std_C      SINAV      LGS  Tur_D  Tur_Y  \
# 0     1     253        ZEYNEP TÜREL    5C  Argon_CDS  488.641   14.0    1.0
# 1     2     104        ASUDE YÜKSEL    5B  Argon_CDS  476.061   14.0    1.0
# 2     3     360       ALPER ÖZDEMİR    5A  Argon_CDS  469.712   13.0    2.0
# 3     4     356            TAHA TAŞ    5A  Argon_CDS  469.488   14.0    1.0
# 4     5     367         BEYZA KILIÇ    5B  Argon_CDS  462.012   14.0    1.0
# 125   1     360       ALPER ÖZDEMİR    5A       Zeka  480.293   15.0    0.0
# 126   2     253        ZEYNEP TÜREL    5C       Zeka  463.360   13.0    2.0
# 127   3     390   NİL BİLGE İZMİRLİ    5A       Zeka  452.607   15.0    0.0
# 128   4     170          DURU ŞAHİN    5A       Zeka  432.640   12.0    3.0
# 129   5     200      KORAY GACARLAR    5B       Zeka  432.193   15.0    0.0
# 202   1     360       ALPER ÖZDEMİR    5A   Mozaik_1  443.880   11.0    4.0
# ...

# %%
df["Std_Name"].value_counts()
# Out:
# ZEYNEP TÜREL        5
# ASUDE YÜKSEL        5
# MERT ARİF ÇITLAK    5
# SEMİH UYANIK        5
# NAZ ALTUNKİREMİT    5
#                    ..
# **D *N  L           1
# MUHAMMETEMİN        1
# ALİYAĞIZÖNCÜL       1
# SUDE BOZ            1
# *****ON  ONUR       1
# Name: Std_Name, Length: 181, dtype: int64

# %%
df["Std_No"].value_counts()
# Out:
# 0       8
# 253     5
# 498     5
# 520     5
# 172     5
#        ..
# 3131    1
# 139     1
# 557     1
# 556     1
# 86      1
# Name: Std_No, Length: 136, dtype: int64

# %%
df[df["Std_No"] == 0]
# Out:
#       NO  Std_No               Std_Name Std_C      SINAV      LGS  Tur_D  \
# 42    43       0           CEREN TÜRKER    5D  Argon_CDS  354.303    8.0
# 110  111       0             MUH*E ***C    5B  Argon_CDS  168.865    6.0
# 118  119       0  ** *N  N            D    5C  Argon_CDS  135.457    6.0
# 120  121       0          EFE ÖZYILM AZ    5D  Argon_CDS  125.896    2.0
# 121  122       0                RU*ĞA*K    *B  Argon_CDS  124.543    7.0
# 197   73       0             A * UN *NR    5C       Zeka  158.547    9.0
# 253   52       0       ECRİNNAZ KORKMAZ    5C   Mozaik_1  215.067    5.0
# 327   53       0        YUSUF ZİYA SARI    5C   Mozaik_3  171.057    3.0
#
#      Tur_Y  Tur_N  Din_D  ...  Fen_N  Top_D  Top_Y  Top_N  Der_C  Der_S  \
# 42     7.0   5.67    6.0  ...  13.67   53.0   22.0  45.68    6.0   43.0
# 110    9.0   3.00    2.0  ...   0.33   28.0   47.0  12.33   29.0  111.0
# 118    9.0   3.00    2.0  ...   3.00   21.0   54.0   2.99   29.0  119.0
# ...

# %%
df[df["Std_Name"].isin(df[df["Std_No"] == 0]["Std_Name"])]
# Out:
#       NO  Std_No               Std_Name Std_C      SINAV      LGS  Tur_D  \
# 42    43       0           CEREN TÜRKER    5D  Argon_CDS  354.303    8.0
# 104  105     126       ECRİNNAZ KORKMAZ    5C  Argon_CDS  189.379    7.0
# 110  111       0             MUH*E ***C    5B  Argon_CDS  168.865    6.0
# 118  119       0  ** *N  N            D    5C  Argon_CDS  135.457    6.0
# 120  121       0          EFE ÖZYILM AZ    5D  Argon_CDS  125.896    2.0
# 121  122       0                RU*ĞA*K    *B  Argon_CDS  124.543    7.0
# 197   73       0             A * UN *NR    5C       Zeka  158.547    9.0
# 253   52       0       ECRİNNAZ KORKMAZ    5C   Mozaik_1  215.067    5.0
# 327   53       0        YUSUF ZİYA SARI    5C   Mozaik_3  171.057    3.0
#
#      Tur_Y  Tur_N  Din_D  ...  Fen_N  Top_D  Top_Y  Top_N  Der_C  Der_S  \
# 42     7.0   5.67    6.0  ...  13.67   53.0   22.0  45.68    6.0   43.0
# 104    8.0   4.33    8.0  ...   1.67   34.0   41.0  20.33   27.0  105.0
# ...

# %%
df.sort_values(by=["Std_No","Std_Name"]).head(20)
# Out:
#       NO  Std_No               Std_Name Std_C      SINAV      LGS  Tur_D  \
# 118  119       0  ** *N  N            D    5C  Argon_CDS  135.457    6.0
# 197   73       0             A * UN *NR    5C       Zeka  158.547    9.0
# 42    43       0           CEREN TÜRKER    5D  Argon_CDS  354.303    8.0
# 253   52       0       ECRİNNAZ KORKMAZ    5C   Mozaik_1  215.067    5.0
# 120  121       0          EFE ÖZYILM AZ    5D  Argon_CDS  125.896    2.0
# 110  111       0             MUH*E ***C    5B  Argon_CDS  168.865    6.0
# 121  122       0                RU*ĞA*K    *B  Argon_CDS  124.543    7.0
# 327   53       0        YUSUF ZİYA SARI    5C   Mozaik_3  171.057    3.0
# 72    73       1         ARDA KAYGISI Z    5A  Argon_CDS  272.385   10.0
# 270   69       1          ARDA KAYGISIZ    5A   Mozaik_1  130.477    NaN
# 384   56       1          ARDA KAYGISIZ    5A   Mozaik_2  223.220   10.0
# 100  101      11       DELFİN ADA ÇULHA    5A  Argon_CDS  197.213    6.0
# ...

# %%
df.groupby("Std_Name")["Std_No"].value_counts().to_frame().head(50)
# Out:
#                               Std_No
# Std_Name              Std_No
# ** *N  N            D 0            1
# *****ON  ONUR         86           1
# **D *N  L             242          1
# *UAM ERAKÇAY          481          1
# *UHAMMEU DOĞANB       317          1
# *ĞURCAN GÜPÜR         111          1
# A * UN *NR            0            1
# A*  ER ** **E         534          1
# ADASU YILMAZ          23           1
# ADASUYILMAZ           23           1
# AKİF EROL             114          2
# ALPER ÖZDEMİR         360          5
# ALİ YAĞIZ ÖNCÜL       252          2
# ALİYAĞIZÖNCÜL         252          1
# ARDA KAYGISI Z        1            1
# ARDA KAYGISIZ         1            2
# ARDA KAĞAN KUTLU      191          1
# ARDA KUTLUCA          191          3
# ASEL BAYRAKTAR        503          2
# ASEL BAYRAKTR         503          1
# ASEL KARAKAYA         265          3
# ASLI ARAT             162          1
#                       622          1
# ...
