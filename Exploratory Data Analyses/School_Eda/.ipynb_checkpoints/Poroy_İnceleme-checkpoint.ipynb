# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams["figure.figsize"] = (12, 8)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
pd.set_option('display.max_columns', None)

# %% [markdown]
# 1. Exceldeki tablolar pythona aktarıldı.

# %%
df_1 = pd.read_excel("5SINIF_1.xlsx")
df_2 = pd.read_excel("5SINIF_2.xlsx")
df_3 = pd.read_excel("5SINIF_3.xlsx")
df_4 = pd.read_excel("5SINIF_4.xlsx")
df_5 = pd.read_excel("5SINIF_5.xlsx")

# %%
display(df_1.head(2), df_2.head(2),df_3.head(2),df_4.head(2),df_5.head(2))
# Out:
#    NO  Std_No      Std_Name Std_C         Tur_D_Y_N         Tar_D_Y_N  \
# 0   1     253  ZEYNEP TÜREL    5C  14     1   13,67  10     0   10,00
# 1   2     104  ASUDE YÜKSEL    5B  14     1   13,67  9      1    8,67
#
#           Din_D_Y_N  Ing_D  Ing_Y  Ing_N  Mat_D  Mat_Y  Mat_N  Fen_D  Fen_Y  \
# 0  9      1    8,67  10.00   0.00  10.00     15      0  15.00     15      0
# 1  9      1    8,67  10.00   0.00  10.00     15      0  15.00     14      1
#
#    Fen_N  Top_D  Top_Y  Top_N    LGS   Der_C_S  Der_Mer  Der_Ama  Der_Gnl
# 0  15.00     73      2  72.34 488.64  1      1        1        1        1
# 1  13.67     71      4  69.68 476.06  1      2        2        2        6
#    NO  Std_No       Std_Name Std_C         Tur_D_Y_N         Tar_D_Y_N  \
# 0   1     360  ALPER ÖZDEMİR    5A  11     4    9,67  10     0   10,00
# 1   2     358       TAHA TAŞ    5A  12     3   11,00  9      1    8,67
#
#           Din_D_Y_N  Ing_D  Ing_Y  Ing_N         Mat_D_Y_N         Fen_D_Y_N  \
# ...

# %% [markdown]
# 2. Dataframe'lere hangi sınava ait oldukları ve sınav tarihleri bilgisi eklendi.

# %%
df_1["SINAV"] = "Argon_CDS"
df_2["SINAV"] = "Mozaik_1"
df_3["SINAV"] = "Zeka"
df_4["SINAV"] = "Mozaik_2"
df_5["SINAV"] = "Mozaik_3"

# %%
df_1["Tarih"] = "10-20-2021"
df_2["Tarih"] = "01-18-2022"
df_3["Tarih"] = "03-07-2022"
df_4["Tarih"] = "12-28-2021"
df_5["Tarih"] = "05-26-2022"

# %%
df_1.shape,df_2.shape,df_3.shape,df_4.shape,df_5.shape
# Out:
# ((125, 26), (73, 22), (77, 26), (73, 22), (54, 22))

# %%
display(df_1.head(2),df_3.head(2))
# Out:
#    NO  Std_No      Std_Name Std_C         Tur_D_Y_N         Tar_D_Y_N  \
# 0   1     253  ZEYNEP TÜREL    5C  14     1   13,67  10     0   10,00
# 1   2     104  ASUDE YÜKSEL    5B  14     1   13,67  9      1    8,67
#
#           Din_D_Y_N  Ing_D  Ing_Y  Ing_N  Mat_D  Mat_Y  Mat_N  Fen_D  Fen_Y  \
# 0  9      1    8,67  10.00   0.00  10.00     15      0  15.00     15      0
# 1  9      1    8,67  10.00   0.00  10.00     15      0  15.00     14      1
#
#    Fen_N  Top_D  Top_Y  Top_N    LGS   Der_C_S  Der_Mer  Der_Ama  Der_Gnl  \
# 0  15.00     73      2  72.34 488.64  1      1        1        1        1
# 1  13.67     71      4  69.68 476.06  1      2        2        2        6
#
#        SINAV       Tarih
# 0  Argon_CDS  10-20-2021
# 1  Argon_CDS  10-20-2021
#    NO  Std_No       Std_Name Std_C         Tur_D_Y_N         Tar_D_Y_N  \
# 0   1     360  ALPER ÖZDEMİR    5A  15     0   15,00  10     0   10,00
# 1   2     253   ZEYNEP TÜREL    5C  13     2   12,33  10     0   10,00
#
# ...

# %% [markdown]
# 3. Aynı sütunlara sahip dataframe'lerin birleştirilmesi yapıldı.

# %%
df_all=pd.concat([df_1,df_3])
df_all.shape
# Out:
# (202, 26)

# %%
display(df_2.head(2),df_4.head(2), df_5.head(2))
# Out:
#    NO  Std_No       Std_Name Std_C         Tur_D_Y_N         Tar_D_Y_N  \
# 0   1     360  ALPER ÖZDEMİR    5A  11     4    9,67  10     0   10,00
# 1   2     358       TAHA TAŞ    5A  12     3   11,00  9      1    8,67
#
#           Din_D_Y_N  Ing_D  Ing_Y  Ing_N         Mat_D_Y_N         Fen_D_Y_N  \
# 0  9      1    8,67  10.00   0.00  10.00  14     1   13,67  14     1   13,67
# 1  8      2    7,33   9.00   1.00   8.67  15     0   15,00  11     4    9,67
#
#    Top_D  Top_Y  Top_N    LGS   Der_C_S  Der_Mer  Der_Ama      Der_Gnl  \
# 0     68      7  65.68 443.88  1      1        1        1  244\n% 0,34
# 1     64     11  60.34 424.09  2      2        2        2  623\n% 0,86
#
#       SINAV       Tarih
# 0  Mozaik_1  01-18-2022
# 1  Mozaik_1  01-18-2022
#    NO  Std_No       Std_Name Std_C         Tur_D_Y_N         Tar_D_Y_N  \
# 0   1     253   ZEYNEP TÜREL    5C  13     2   12,33  10     0   10,00
# 1   2     360  ALPER ÖZDEMİR    5A  13     2   12,33  9      1    8,67
#
# ...

# %%
df_other=pd.concat([df_2,df_4,df_5])
df_other.shape
# Out:
# (200, 22)

# %% [markdown]
# 4. Birleştirilen dataframe'ler extract metodu ile parçalanarak aynı formata getirildi

# %%
df_all.head()
# Out:
#    NO  Std_No       Std_Name Std_C         Tur_D_Y_N         Tar_D_Y_N  \
# 0   1     253   ZEYNEP TÜREL    5C  14     1   13,67  10     0   10,00
# 1   2     104   ASUDE YÜKSEL    5B  14     1   13,67  9      1    8,67
# 2   3     360  ALPER ÖZDEMİR    5A  13     2   12,33  8      2    7,33
# 3   4     356       TAHA TAŞ    5A  14     1   13,67  9      1    8,67
# 4   5     367    BEYZA KILIÇ    5B  14     1   13,67  10     0   10,00
#
#           Din_D_Y_N  Ing_D  Ing_Y  Ing_N  Mat_D  Mat_Y  Mat_N  Fen_D  Fen_Y  \
# 0  9      1    8,67  10.00   0.00  10.00     15      0  15.00     15      0
# 1  9      1    8,67  10.00   0.00  10.00     15      0  15.00     14      1
# 2  10     0   10,00   8.00   2.00   7.33     15      0  15.00     15      0
# 3  10     0   10,00   4.00   3.00   3.00     15      0  15.00     15      0
# 4  10     0   10,00  10.00   0.00  10.00     13      2  12.33     14      0
#
#    Fen_N  Top_D  Top_Y  Top_N    LGS   Der_C_S  Der_Mer  Der_Ama Der_Gnl  \
# ...

# %%
ex_Tur = df_all["Tur_D_Y_N"].str.extract("(\d+)\s+(\d\d?)\s+(.*)")
ex_Tar = df_all["Tar_D_Y_N"].str.extract("(\d+)\s+(\d\d?)\s+(.*)")
ex_Din = df_all["Din_D_Y_N"].str.extract("(\d+)\s+(\d\d?)\s+(.*)")

# %%
df_all[["Tur_D","Tur_Y","Tur_N"]] = ex_Tur
df_all[["Tar_D","Tar_Y","Tar_N"]] = ex_Tar
df_all[["Din_D","Din_Y","Din_N"]] = ex_Din
df_all.head(2)
# Out:
#    NO  Std_No      Std_Name Std_C         Tur_D_Y_N         Tar_D_Y_N  \
# 0   1     253  ZEYNEP TÜREL    5C  14     1   13,67  10     0   10,00
# 1   2     104  ASUDE YÜKSEL    5B  14     1   13,67  9      1    8,67
#
#           Din_D_Y_N  Ing_D  Ing_Y  Ing_N  Mat_D  Mat_Y  Mat_N  Fen_D  Fen_Y  \
# 0  9      1    8,67  10.00   0.00  10.00     15      0  15.00     15      0
# 1  9      1    8,67  10.00   0.00  10.00     15      0  15.00     14      1
#
#    Fen_N  Top_D  Top_Y  Top_N    LGS   Der_C_S  Der_Mer  Der_Ama Der_Gnl  \
# 0  15.00     73      2  72.34 488.64  1      1        1        1       1
# 1  13.67     71      4  69.68 476.06  1      2        2        2       6
#
#        SINAV       Tarih Tur_D Tur_Y  Tur_N Tar_D Tar_Y  Tar_N Din_D Din_Y  \
# 0  Argon_CDS  10-20-2021    14     1  13,67    10     0  10,00     9     1
# 1  Argon_CDS  10-20-2021    14     1  13,67     9     1   8,67     9     1
#
#   Din_N
# 0  8,67
# 1  8,67

# %%
df_all.drop(columns=["Tur_D_Y_N","Tar_D_Y_N","Din_D_Y_N"], inplace=True)
df_all.shape
# Out:
# (202, 32)

# %%
df_all[["Der_C","Der_S"]] =df_all["Der_C_S"].str.extract("(\d+)\s+(\d+)")
df_all.drop(columns=["Der_C_S"], inplace=True)

# %%
df_all.head(2)
# Out:
#    NO  Std_No      Std_Name Std_C  Ing_D  Ing_Y  Ing_N  Mat_D  Mat_Y  Mat_N  \
# 0   1     253  ZEYNEP TÜREL    5C  10.00   0.00  10.00     15      0  15.00
# 1   2     104  ASUDE YÜKSEL    5B  10.00   0.00  10.00     15      0  15.00
#
#    Fen_D  Fen_Y  Fen_N  Top_D  Top_Y  Top_N    LGS  Der_Mer  Der_Ama Der_Gnl  \
# 0     15      0  15.00     73      2  72.34 488.64        1        1       1
# 1     14      1  13.67     71      4  69.68 476.06        2        2       6
#
#        SINAV       Tarih Tur_D Tur_Y  Tur_N Tar_D Tar_Y  Tar_N Din_D Din_Y  \
# 0  Argon_CDS  10-20-2021    14     1  13,67    10     0  10,00     9     1
# 1  Argon_CDS  10-20-2021    14     1  13,67     9     1   8,67     9     1
#
#   Din_N Der_C Der_S
# 0  8,67     1     1
# 1  8,67     1     2

# %%
df_other.columns
# Out:
# Index(['NO', 'Std_No', 'Std_Name', 'Std_C', 'Tur_D_Y_N', 'Tar_D_Y_N',
#        'Din_D_Y_N', 'Ing_D', 'Ing_Y', 'Ing_N', 'Mat_D_Y_N', 'Fen_D_Y_N',
#        'Top_D', 'Top_Y', 'Top_N', 'LGS', 'Der_C_S', 'Der_Mer', 'Der_Ama',
#        'Der_Gnl', 'SINAV', 'Tarih'],
#       dtype='object')

# %%
ex_Tur = df_other["Tur_D_Y_N"].str.extract("(\d+)\s+(\d\d?)\s+(.*)")
ex_Tar = df_other["Tar_D_Y_N"].str.extract("(\d+)\s+(\d\d?)\s+(.*)")
ex_Din = df_other["Din_D_Y_N"].str.extract("(\d+)\s+(\d\d?)\s+(.*)")
ex_Mat = df_other["Mat_D_Y_N"].str.extract("(\d+)\s+(\d\d?)\s+(.*)")
ex_Fen = df_other["Fen_D_Y_N"].str.extract("(\d+)\s+(\d\d?)\s+(.*)")
df_other[["Der_C","Der_S"]] = df_other["Der_C_S"].str.extract("(\d+)\s+(\d+)")

# %%
df_other[["Tur_D","Tur_Y","Tur_N"]] = ex_Tur
df_other[["Tar_D","Tar_Y","Tar_N"]] = ex_Tar
df_other[["Din_D","Din_Y","Din_N"]] = ex_Din
df_other[["Mat_D","Mat_Y","Mat_N"]] = ex_Mat
df_other[["Fen_D","Fen_Y","Fen_N"]] = ex_Fen

df_other.head()
# Out:
#    NO  Std_No            Std_Name Std_C         Tur_D_Y_N         Tar_D_Y_N  \
# 0   1     360       ALPER ÖZDEMİR    5A  11     4    9,67  10     0   10,00
# 1   2     358            TAHA TAŞ    5A  12     3   11,00  9      1    8,67
# 2   3     390   NİL BİLGE İZMİRLİ    5A  11     2   10,33  9      1    8,67
# 3   4     397  MELİK KAAN ÖZÇELİK    5A  10     3    9,00  9      1    8,67
# 4   5     156      ÇINAR GÜNGÖREN    5A  10     5    8,33  10     0   10,00
#
#           Din_D_Y_N  Ing_D  Ing_Y  Ing_N         Mat_D_Y_N         Fen_D_Y_N  \
# 0  9      1    8,67  10.00   0.00  10.00  14     1   13,67  14     1   13,67
# 1  8      2    7,33   9.00   1.00   8.67  15     0   15,00  11     4    9,67
# 2  9      1    8,67  10.00   0.00  10.00  11     1   10,67  14     1   13,67
# 3  10     0   10,00  10.00   0.00  10.00  12     1   11,67  13     2   12,33
# 4  7      1    6,67  10.00   0.00  10.00  11     1   10,67  14     1   13,67
#
# ...

# %%
df_other.drop(columns=["Tur_D_Y_N","Tar_D_Y_N","Din_D_Y_N","Mat_D_Y_N","Fen_D_Y_N","Der_C_S"], inplace=True)

# %%
df_other.shape,df_all.shape
# Out:
# ((200, 33), (202, 33))

# %%
display(df_other.head(1),df_all.head(1))
# Out:
#    NO  Std_No       Std_Name Std_C  Ing_D  Ing_Y  Ing_N  Top_D  Top_Y  Top_N  \
# 0   1     360  ALPER ÖZDEMİR    5A  10.00   0.00  10.00     68      7  65.68
#
#      LGS  Der_Mer  Der_Ama      Der_Gnl     SINAV       Tarih Der_C Der_S  \
# 0 443.88        1        1  244\n% 0,34  Mozaik_1  01-18-2022     1     1
#
#   Tur_D Tur_Y Tur_N Tar_D Tar_Y  Tar_N Din_D Din_Y Din_N Mat_D Mat_Y  Mat_N  \
# 0    11     4  9,67    10     0  10,00     9     1  8,67    14     1  13,67
#
#   Fen_D Fen_Y  Fen_N
# 0    14     1  13,67
#    NO  Std_No      Std_Name Std_C  Ing_D  Ing_Y  Ing_N  Mat_D  Mat_Y  Mat_N  \
# 0   1     253  ZEYNEP TÜREL    5C  10.00   0.00  10.00     15      0  15.00
#
#    Fen_D  Fen_Y  Fen_N  Top_D  Top_Y  Top_N    LGS  Der_Mer  Der_Ama Der_Gnl  \
# 0     15      0  15.00     73      2  72.34 488.64        1        1       1
#
#        SINAV       Tarih Tur_D Tur_Y  Tur_N Tar_D Tar_Y  Tar_N Din_D Din_Y  \
# ...

# %% [markdown]
# 5. Parçalanarak aynı formata getirilen dataframe'ler birleştirildi.

# %%
df_all = pd.concat([df_all,df_other])
df = df_all.copy()
df.shape
# Out:
# (402, 33)

# %% [markdown]
# # 1. Data Anlama

# %%
df.head(5)
# Out:
#    NO  Std_No       Std_Name Std_C  Ing_D  Ing_Y  Ing_N Mat_D Mat_Y Mat_N  \
# 0   1     253   ZEYNEP TÜREL    5C  10.00   0.00  10.00    15     0 15.00
# 1   2     104   ASUDE YÜKSEL    5B  10.00   0.00  10.00    15     0 15.00
# 2   3     360  ALPER ÖZDEMİR    5A   8.00   2.00   7.33    15     0 15.00
# 3   4     356       TAHA TAŞ    5A   4.00   3.00   3.00    15     0 15.00
# 4   5     367    BEYZA KILIÇ    5B  10.00   0.00  10.00    13     2 12.33
#
#   Fen_D Fen_Y Fen_N  Top_D  Top_Y  Top_N    LGS  Der_Mer  Der_Ama Der_Gnl  \
# 0    15     0 15.00     73      2  72.34 488.64        1        1       1
# 1    14     1 13.67     71      4  69.68 476.06        2        2       6
# 2    15     0 15.00     69      6  66.99 469.71        3        3      12
# 3    15     0 15.00     67      5  65.34 469.49        4        4      13
# 4    14     0 14.00     71      3  70.00 462.01        5        5      25
#
# ...

# %%
df.columns
# Out:
# Index(['NO', 'Std_No', 'Std_Name', 'Std_C', 'Ing_D', 'Ing_Y', 'Ing_N', 'Mat_D',
#        'Mat_Y', 'Mat_N', 'Fen_D', 'Fen_Y', 'Fen_N', 'Top_D', 'Top_Y', 'Top_N',
#        'LGS', 'Der_Mer', 'Der_Ama', 'Der_Gnl', 'SINAV', 'Tarih', 'Tur_D',
#        'Tur_Y', 'Tur_N', 'Tar_D', 'Tar_Y', 'Tar_N', 'Din_D', 'Din_Y', 'Din_N',
#        'Der_C', 'Der_S'],
#       dtype='object')

# %% [markdown]
# 6. Sütunların formata uygun şekilde sıralandırılması yapıldı

# %%
df = df[['NO','Std_No', 'Std_Name', 'Std_C', 'SINAV', 'LGS',
         'Tur_D', 'Tur_Y', 'Tur_N', 'Din_D','Din_Y', 'Din_N', 'Tar_D', 'Tar_Y', 'Tar_N',
         'Ing_D',  'Ing_Y','Ing_N','Mat_D',  'Mat_Y','Mat_N', 'Fen_D',  'Fen_Y','Fen_N', 'Top_D',  'Top_Y','Top_N',
         'Der_C','Der_S','Der_Mer','Der_Ama','Der_Gnl','Tarih' ]]

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head(3)
# Out:
#    NO  Std_No       Std_Name Std_C      SINAV    LGS Tur_D Tur_Y  Tur_N Din_D  \
# 0   1     253   ZEYNEP TÜREL    5C  Argon_CDS 488.64    14     1  13,67     9
# 1   2     104   ASUDE YÜKSEL    5B  Argon_CDS 476.06    14     1  13,67     9
# 2   3     360  ALPER ÖZDEMİR    5A  Argon_CDS 469.71    13     2  12,33    10
#
#   Din_Y  Din_N Tar_D Tar_Y  Tar_N  Ing_D  Ing_Y  Ing_N Mat_D Mat_Y Mat_N  \
# 0     1   8,67    10     0  10,00  10.00   0.00  10.00    15     0 15.00
# 1     1   8,67     9     1   8,67  10.00   0.00  10.00    15     0 15.00
# 2     0  10,00     8     2   7,33   8.00   2.00   7.33    15     0 15.00
#
#   Fen_D Fen_Y Fen_N  Top_D  Top_Y  Top_N Der_C Der_S  Der_Mer  Der_Ama  \
# 0    15     0 15.00     73      2  72.34     1     1        1        1
# 1    14     1 13.67     71      4  69.68     1     2        2        2
# 2    15     0 15.00     69      6  66.99     1     3        3        3
#
#   Der_Gnl       Tarih
# 0       1  10-20-2021
# 1       6  10-20-2021
# ...

# %% [markdown]
# 7. İçerisinde "," olan sayısal değerler "." ile değiştirildi ve sata tipleri ayarlandı.

# %%
for i in df.select_dtypes(include=object).columns:
    df[i] = df[i].transform(lambda x: str(x).replace(",",".") if "," in str(x) else str(x))
df.sample(5)
# Out:
#       NO  Std_No           Std_Name Std_C      SINAV    LGS Tur_D Tur_Y  \
# 113  114     223            ELAEKIM    5A  Argon_CDS 156.67     6     9
# 106  107     556   E*İRHAN SARIKAYA    5D  Argon_CDS 176.63     6     9
# 297   23      78  ÇAĞAN IŞIK AKSOĞA    5B   Mozaik_2 356.77    11     4
# 384   37     517  ÖMER T* A YAHNİCİ    5C   Mozaik_3 280.00     7     7
# 14    15     388  AYŞE ELİF ERGÜLER    5B  Argon_CDS 435.33    14     1
#
#      Tur_N Din_D Din_Y  Din_N Tar_D Tar_Y Tar_N  Ing_D  Ing_Y  Ing_N Mat_D  \
# 113   3.00     0    10  -3.33     6     4  4.67   3.00   7.00   0.67     5
# 106   3.00     3     7   0.67     3     7  0.67   4.00   5.00   2.33     7
# 297   9.67     9     1   8.67     9     1  8.67   8.00   2.00   7.33    11
# 384   4.67     9     1   8.67     7     3  6.00   6.00   4.00   4.67     9
# 14   13.67     7     3   6.00     8     2  7.33  10.00   0.00  10.00    13
#
#     Mat_Y  Mat_N Fen_D Fen_Y  Fen_N  Top_D  Top_Y  Top_N Der_C Der_S  Der_Mer  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 402 entries, 0 to 401
# Data columns (total 33 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   NO        402 non-null    int64
#  1   Std_No    402 non-null    int64
#  2   Std_Name  402 non-null    object
#  3   Std_C     402 non-null    object
#  4   SINAV     402 non-null    object
#  5   LGS       402 non-null    float64
#  6   Tur_D     402 non-null    object
#  7   Tur_Y     402 non-null    object
#  8   Tur_N     402 non-null    object
#  9   Din_D     402 non-null    object
#  10  Din_Y     402 non-null    object
#  11  Din_N     402 non-null    object
#  12  Tar_D     402 non-null    object
#  13  Tar_Y     402 non-null    object
#  14  Tar_N     402 non-null    object
#  15  Ing_D     399 non-null    float64
#  16  Ing_Y     399 non-null    float64
#  17  Ing_N     399 non-null    float64
#  18  Mat_D     402 non-null    object
#  19  Mat_Y     402 non-null    object
# ...

# %%
df.iloc[:,5:31] = df.iloc[:,5:31].astype(float)

# %% [markdown]
# 8. Son sütundaki yer alan bilgilerden sadece genel derece alındı ve ilgili sütun float tipine çevrildi.

# %%
df["Der_Gnl"].sample(20)
# Out:
# 20              150
# 164     17212\n% 17
# 358     415\n% 4.22
# 224    6191\n% 8.51
# 351     188\n% 1.91
# 243     15172\n% 21
# 362     540\n% 5.50
# 387      2844\n% 29
# 2                12
# 90             1274
# 60              658
# 342     22008\n% 68
# 135    1948\n% 1.89
# 174     27374\n% 27
# 196     66030\n% 64
# 336     19398\n% 60
# 7                42
# 77              958
# 78             1009
# 363     564\n% 5.74
# Name: Der_Gnl, dtype: object

# %%
df["Der_Gnl"] = df["Der_Gnl"].str.extract("(\d+)").astype(float)
df["Der_Gnl"]
# Out:
# 0        1.00
# 1        6.00
# 2       12.00
# 3       13.00
# 4       25.00
#         ...
# 397   5039.00
# 398   5259.00
# 399   5377.00
# 400   5524.00
# 401   8069.00
# Name: Der_Gnl, Length: 402, dtype: float64

# %%
df["Tarih"] = pd.to_datetime(df["Tarih"])

# %% [markdown]
# 9. Sınav bazında oransal olarak tespit yapabilmek adına sınava giren kişi sayıları dataframe'e eklendi.

# %%
df.groupby("SINAV").head(2)
# Out:
#      NO  Std_No       Std_Name Std_C      SINAV    LGS  Tur_D  Tur_Y  Tur_N  \
# 0     1     253   ZEYNEP TÜREL    5C  Argon_CDS 488.64  14.00   1.00  13.67
# 1     2     104   ASUDE YÜKSEL    5B  Argon_CDS 476.06  14.00   1.00  13.67
# 125   1     360  ALPER ÖZDEMİR    5A       Zeka 480.29  15.00   0.00  15.00
# 126   2     253   ZEYNEP TÜREL    5C       Zeka 463.36  13.00   2.00  12.33
# 202   1     360  ALPER ÖZDEMİR    5A   Mozaik_1 443.88  11.00   4.00   9.67
# 203   2     358       TAHA TAŞ    5A   Mozaik_1 424.09  12.00   3.00  11.00
# 275   1     253   ZEYNEP TÜREL    5C   Mozaik_2 444.07  13.00   2.00  12.33
# 276   2     360  ALPER ÖZDEMİR    5A   Mozaik_2 435.51  13.00   2.00  12.33
# 348   1     360  ALPER ÖZDEMİR    5A   Mozaik_3 431.41  13.00   2.00  12.33
# 349   2     104   ASUDE YÜKSEL    5B   Mozaik_3 417.96  14.00   1.00  13.67
#
#      Din_D  Din_Y  Din_N  Tar_D  Tar_Y  Tar_N  Ing_D  Ing_Y  Ing_N  Mat_D  \
# ...

# %%
df["TotaL"]=df["SINAV"].transform(lambda x: 1970 if x == "Argon_CDS" else (72784 if x == "Mozaik_1" else (103126 if x == "Zeka" else (32439 if x == "Mozaik_2" else 9826))))

# %%
df.groupby("SINAV").head(5)
# Out:
#      NO  Std_No            Std_Name Std_C      SINAV    LGS  Tur_D  Tur_Y  \
# 0     1     253        ZEYNEP TÜREL    5C  Argon_CDS 488.64  14.00   1.00
# 1     2     104        ASUDE YÜKSEL    5B  Argon_CDS 476.06  14.00   1.00
# 2     3     360       ALPER ÖZDEMİR    5A  Argon_CDS 469.71  13.00   2.00
# 3     4     356            TAHA TAŞ    5A  Argon_CDS 469.49  14.00   1.00
# 4     5     367         BEYZA KILIÇ    5B  Argon_CDS 462.01  14.00   1.00
# 125   1     360       ALPER ÖZDEMİR    5A       Zeka 480.29  15.00   0.00
# 126   2     253        ZEYNEP TÜREL    5C       Zeka 463.36  13.00   2.00
# 127   3     390   NİL BİLGE İZMİRLİ    5A       Zeka 452.61  15.00   0.00
# 128   4     170          DURU ŞAHİN    5A       Zeka 432.64  12.00   3.00
# 129   5     200      KORAY GACARLAR    5B       Zeka 432.19  15.00   0.00
# 202   1     360       ALPER ÖZDEMİR    5A   Mozaik_1 443.88  11.00   4.00
# 203   2     358            TAHA TAŞ    5A   Mozaik_1 424.09  12.00   3.00
# ...

# %% [markdown]
# 10. Std No'lar esas alınarak yanlış veri girişleri düzeltildi.

# %%
df["Std_Name"].value_counts().head(20)
# Out:
# ZEYNEP TÜREL          5
# ASUDE YÜKSEL          5
# MERT ARİF ÇITLAK      5
# SEMİH UYANIK          5
# NAZ ALTUNKİREMİT      5
# YAĞIZ TAZEGÜL         5
# BİLGE BAL             5
# TUNA GÜRLE            5
# ÇAĞAN EMRE GEGİN      5
# YUSUF DEMİRCİ         5
# ECRİN HÜMA İZGİ       5
# UMUT PEHLİVAN         5
# ZELİHA CEBECİOĞLU     5
# MELİK KAAN ÖZÇELİK    5
# ALPER ÖZDEMİR         5
# TAHA TAŞ              5
# ÇAĞAN IŞIK AKSOĞA     5
# BEYZA KILIÇ           5
# KORAY GACARLAR        5
# EYLÜL AKTAŞ           4
# Name: Std_Name, dtype: int64

# %%
df["Std_Name"].value_counts().tail(20)
# Out:
# YİĞİT KORKMAZ       1
# A*  ER ** **E       1
# ELAEKIM             1
# CEMALBARANOKYAY     1
# MUH*E ***C          1
# POYRAZKIRIMLI       1
# E*İRHAN SARIKAYA    1
# MUSTAFA ÇANAKÇI     1
# *ĞURCAN GÜPÜR       1
# ŞEFİKA GULİYEVA     1
# İREMSUAYDOĞDU       1
# CEREN A Y*LI        1
# ENES EMRE TANCI     1
# HİRANUR ŞEKER       1
# BEGÜM YILMAZ        1
# **D *N  L           1
# MUHAMMETEMİN        1
# ALİYAĞIZÖNCÜL       1
# SUDE BOZ            1
# YUSUF ZİYA SARI     1
# Name: Std_Name, dtype: int64

# %%
df[df["Std_No"] == 0]
# Out:
#       NO  Std_No               Std_Name Std_C      SINAV    LGS  Tur_D  Tur_Y  \
# 42    43       0           CEREN TÜRKER    5D  Argon_CDS 354.30   8.00   7.00
# 110  111       0             MUH*E ***C    5B  Argon_CDS 168.87   6.00   9.00
# 118  119       0  ** *N  N            D    5C  Argon_CDS 135.46   6.00   9.00
# 120  121       0          EFE ÖZYILM AZ    5D  Argon_CDS 125.90   2.00  13.00
# 121  122       0                RU*ĞA*K    *B  Argon_CDS 124.54   7.00   8.00
# 197   73       0             A * UN *NR    5C       Zeka 158.55   9.00   6.00
# 253   52       0       ECRİNNAZ KORKMAZ    5C   Mozaik_1 215.07   5.00  10.00
# 400   53       0        YUSUF ZİYA SARI    5C   Mozaik_3 171.06   3.00   9.00
#
#      Tur_N  Din_D  Din_Y  Din_N  Tar_D  Tar_Y  Tar_N  Ing_D  Ing_Y  Ing_N  \
# 42    5.67   6.00   4.00   4.67   8.00   2.00   7.33   6.00   4.00   4.67
# 110   3.00   2.00   8.00  -0.67   6.00   4.00   4.67   3.00   7.00   0.67
# ...

# %%
df["Unified_Name"] = df["Std_Name"].str.replace(" ","")
df
# Out:
#      NO  Std_No          Std_Name Std_C      SINAV    LGS  Tur_D  Tur_Y  \
# 0     1     253      ZEYNEP TÜREL    5C  Argon_CDS 488.64  14.00   1.00
# 1     2     104      ASUDE YÜKSEL    5B  Argon_CDS 476.06  14.00   1.00
# 2     3     360     ALPER ÖZDEMİR    5A  Argon_CDS 469.71  13.00   2.00
# 3     4     356          TAHA TAŞ    5A  Argon_CDS 469.49  14.00   1.00
# 4     5     367       BEYZA KILIÇ    5B  Argon_CDS 462.01  14.00   1.00
# ..   ..     ...               ...   ...        ...    ...    ...    ...
# 397  50     470      AYŞE KARAKOÇ    5B   Mozaik_3 181.53   6.00   9.00
# 398  51     254    POYRAZ KIRIMLI    5C   Mozaik_3 176.68  11.00   3.00
# 399  52     145        MELİS PALA    5B   Mozaik_3 174.11   8.00   6.00
# 400  53       0   YUSUF ZİYA SARI    5C   Mozaik_3 171.06   3.00   9.00
# 401  54      11  DELFİN ADA ÇULHA    5A   Mozaik_3 122.42   4.00  11.00
#
#      Tur_N  Din_D  Din_Y  Din_N  Tar_D  Tar_Y  Tar_N  Ing_D  Ing_Y  Ing_N  \
# ...

# %%
df[df["Unified_Name"].isin(df[df["Std_No"] == 0]["Unified_Name"])]
#Bu kod ile Ecrinnaz Korkmaz'ın başka bir yerde numarasının farklı olduğu görüldü
# Out:
#       NO  Std_No               Std_Name Std_C      SINAV    LGS  Tur_D  Tur_Y  \
# 42    43       0           CEREN TÜRKER    5D  Argon_CDS 354.30   8.00   7.00
# 104  105     126       ECRİNNAZ KORKMAZ    5C  Argon_CDS 189.38   7.00   8.00
# 110  111       0             MUH*E ***C    5B  Argon_CDS 168.87   6.00   9.00
# 118  119       0  ** *N  N            D    5C  Argon_CDS 135.46   6.00   9.00
# 120  121       0          EFE ÖZYILM AZ    5D  Argon_CDS 125.90   2.00  13.00
# 121  122       0                RU*ĞA*K    *B  Argon_CDS 124.54   7.00   8.00
# 197   73       0             A * UN *NR    5C       Zeka 158.55   9.00   6.00
# 253   52       0       ECRİNNAZ KORKMAZ    5C   Mozaik_1 215.07   5.00  10.00
# 400   53       0        YUSUF ZİYA SARI    5C   Mozaik_3 171.06   3.00   9.00
#
#      Tur_N  Din_D  Din_Y  Din_N  Tar_D  Tar_Y  Tar_N  Ing_D  Ing_Y  Ing_N  \
# 42    5.67   6.00   4.00   4.67   8.00   2.00   7.33   6.00   4.00   4.67
# ...

# %%
# df_new = df.groupby("Std_No")["Unified_Name"].value_counts().to_frame(name="count").reset_index()
# df[df["Unified_Name"].isin(df_new[df_new["Std_No"]==275]["Unified_Name"])]

# %% [markdown]
# 11. Std_No aynı olan ama farklı isimlere sahip olan kayıtlar tespit edildi

# %%
again_list=[]
for i in df["Std_No"].unique():
    if len(df[df["Std_No"] == i]["Unified_Name"].value_counts()) > 1:
        again_list += [i]

# %%
# df[df["Std_No"].isin(again_list)].sort_values("Std_No").iloc[90:] # Göz ile kontrol

# %%
again_name_list=[]
for i in df["Unified_Name"].unique():
    if len(df[df["Unified_Name"] == i]["Std_No"].value_counts()) > 1:
        again_name_list += [i]

# %%
# df[df["Unified_Name"].isin(again_name_list)].sort_values("Unified_Name")  # Göz ile kontrol

# %% [markdown]
# 12. Yapılan gözle kontroller neticesinde yanlış olan Std_No lar değiştirildi

# %%
df.loc[251,"Std_No"]=215
df.loc[162,"Std_No"]=558
df.loc[56,"Std_No"]=162
df.loc[268, "Std_No"]=376
df.loc[400,"Std_No"]=99
df.loc[253,"Std_No"]=126
df.loc[70,"Std_No"]=159
df.loc[353,"Std_No"]=490
df.loc[92,"Std_No"]=332
df.loc[65,"Std_No"]=527
df.loc[325,"Std_No"]=524
df.loc[193,"Std_No"]=524
df.loc[3,"Std_No"]=358
df.loc[327,"Std_No"]=543

# %% [markdown]
# 13. Std_No "0" olanlara öğrenci numarası verildi

# %%
df["Std_No"].value_counts(dropna=False)
# Out:
# 0       6
# 498     5
# 524     5
# 329     5
# 520     5
#        ..
# 3131    1
# 539     1
# 193     1
# 243     1
# 254     1
# Name: Std_No, Length: 131, dtype: int64

# %%
df.loc[df["Std_No"]==0,"Std_No"] = np.arange(622,628)

# %%
df.loc[df["Std_No"]==0]
# Out:
# Empty DataFrame
# Columns: [NO, Std_No, Std_Name, Std_C, SINAV, LGS, Tur_D, Tur_Y, Tur_N, Din_D, Din_Y, Din_N, Tar_D, Tar_Y, Tar_N, Ing_D, Ing_Y, Ing_N, Mat_D, Mat_Y, Mat_N, Fen_D, Fen_Y, Fen_N, Top_D, Top_Y, Top_N, Der_C, Der_S, Der_Mer, Der_Ama, Der_Gnl, Tarih, TotaL, Unified_Name]
# Index: []

# %% [markdown]
# 14. Std_C deki yanlış girişler düzeltildi

# %%
df["Std_C"].unique()
# Out:
# array(['5C', '5B', '5A', '5D', '**', '*B', '5Ç'], dtype=object)

# %%
df.loc[df["Std_C"].str.contains("Ç"),"Std_C"]="5C"
df.loc[df["Std_C"].str.contains("B"),"Std_C"]="5B"
df.loc[df["Std_C"].str.contains("\*"),"Std_C"] = "5D"

# %%
df["Std_C"].unique()
# Out:
# array(['5C', '5B', '5A', '5D'], dtype=object)

# %% [markdown]
# 15. Null değerler kontrol edildi düzeltildi

# %%
df[df["Tur_D"].isnull()].iloc[:,5:25]
# Out:
#        LGS  Tur_D  Tur_Y  Tur_N  Din_D  Din_Y  Din_N  Tar_D  Tar_Y  Tar_N  \
# 268 142.72    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 269 135.76    NaN    NaN    NaN   8.00   2.00   7.33   5.00   5.00   3.33
# 270 130.48    NaN    NaN    NaN   5.00   5.00   3.33   4.00   6.00   2.00
# 271 129.05    NaN    NaN    NaN   2.00   7.00  -0.33   5.00   5.00   3.33
# 272 108.17    NaN    NaN    NaN   5.00   5.00   3.33   4.00   6.00   2.00
# 273 105.81    NaN    NaN    NaN   4.00   5.00   2.33   0.00  10.00  -3.33
# 274 102.09    NaN    NaN    NaN   2.00   8.00  -0.67   1.00   9.00  -2.00
#
#      Ing_D  Ing_Y  Ing_N  Mat_D  Mat_Y  Mat_N  Fen_D  Fen_Y  Fen_N  Top_D
# 268    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN   7.00
# 269   7.00   3.00   6.00   1.00  11.00  -2.67   1.00   9.00  -2.00  27.00
# 270   4.00   6.00   2.00   2.00  10.00  -1.33   5.00   9.00   2.00  23.00
# 271   2.00   8.00  -0.67   3.00  12.00  -1.00   5.00  10.00   1.67  21.00
# ...

# %%
# df.iloc[((~pd.Series(np.arange(401)).isin(df.dropna(thresh=17,axis=0).index))*1).idxmax()]
df.dropna(thresh=17,axis=0,inplace=True) # 268. satır da değerler null olduğu için çıkarıldı

# %%
df.isnull().sum()
# Out:
# NO              0
# Std_No          0
# Std_Name        0
# Std_C           0
# SINAV           0
# LGS             0
# Tur_D           7
# Tur_Y           7
# Tur_N           7
# Din_D           3
# Din_Y           3
# Din_N           3
# Tar_D           1
# Tar_Y           1
# Tar_N           1
# Ing_D           3
# Ing_Y           3
# Ing_N           3
# Mat_D           1
# Mat_Y           1
# Mat_N           1
# Fen_D           2
# Fen_Y           2
# Fen_N           2
# Top_D           0
# Top_Y           0
# Top_N           0
# Der_C           0
# Der_S           0
# Der_Mer         0
# Der_Ama         0
# Der_Gnl         0
# Tarih           0
# TotaL           0
# Unified_Name    0
# dtype: int64

# %%
df.fillna(0,inplace=True)

# %%
df.isnull().sum()
# Out:
# NO              0
# Std_No          0
# Std_Name        0
# Std_C           0
# SINAV           0
# LGS             0
# Tur_D           0
# Tur_Y           0
# Tur_N           0
# Din_D           0
# Din_Y           0
# Din_N           0
# Tar_D           0
# Tar_Y           0
# Tar_N           0
# Ing_D           0
# Ing_Y           0
# Ing_N           0
# Mat_D           0
# Mat_Y           0
# Mat_N           0
# Fen_D           0
# Fen_Y           0
# Fen_N           0
# Top_D           0
# Top_Y           0
# Top_N           0
# Der_C           0
# Der_S           0
# Der_Mer         0
# Der_Ama         0
# Der_Gnl         0
# Tarih           0
# TotaL           0
# Unified_Name    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 402 entries, 0 to 401
# Data columns (total 35 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   NO            402 non-null    int64
#  1   Std_No        402 non-null    int64
#  2   Std_Name      402 non-null    object
#  3   Std_C         402 non-null    object
#  4   SINAV         402 non-null    object
#  5   LGS           402 non-null    float64
#  6   Tur_D         402 non-null    float64
#  7   Tur_Y         402 non-null    float64
#  8   Tur_N         402 non-null    float64
#  9   Din_D         402 non-null    float64
#  10  Din_Y         402 non-null    float64
#  11  Din_N         402 non-null    float64
#  12  Tar_D         402 non-null    float64
#  13  Tar_Y         402 non-null    float64
#  14  Tar_N         402 non-null    float64
#  15  Ing_D         402 non-null    float64
#  16  Ing_Y         402 non-null    float64
#  17  Ing_N         402 non-null    float64
# ...

# %%
df = df.sort_values(by=["Tarih","NO"]).reset_index(drop=True)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>16. Data temizlendi, analiz kısmına geçildi</b>
# </div>

# %% [markdown]
# 1. Sınıflar arası başarı durumu
# 2. Sınavlara göre başarı durumu
# 3. Dönem ilerledikçe başarı durumu değişen sınıflar
# 4. Dönem ilerledikçe başarı durumu değişen 10 öğrenci
# 5. Yarıyıl tatilinden sonra Matemetik öğretmeni değişti. Başarı durumunda değişiklik oldu mu..
# 6. Ders bazında en iyi sınıf sıralaması

# %%
(df["Std_No"].value_counts() > 1).sum()
# Out:
# 99

# %%
df.head(3)
# Out:
#    NO  Std_No       Std_Name Std_C      SINAV    LGS  Tur_D  Tur_Y  Tur_N  \
# 0   1     253   ZEYNEP TÜREL    5C  Argon_CDS 488.64  14.00   1.00  13.67
# 1   2     104   ASUDE YÜKSEL    5B  Argon_CDS 476.06  14.00   1.00  13.67
# 2   3     360  ALPER ÖZDEMİR    5A  Argon_CDS 469.71  13.00   2.00  12.33
#
#    Din_D  Din_Y  Din_N  Tar_D  Tar_Y  Tar_N  Ing_D  Ing_Y  Ing_N  Mat_D  \
# 0   9.00   1.00   8.67  10.00   0.00  10.00  10.00   0.00  10.00  15.00
# 1   9.00   1.00   8.67   9.00   1.00   8.67  10.00   0.00  10.00  15.00
# 2  10.00   0.00  10.00   8.00   2.00   7.33   8.00   2.00   7.33  15.00
#
#    Mat_Y  Mat_N  Fen_D  Fen_Y  Fen_N  Top_D  Top_Y  Top_N  Der_C  Der_S  \
# 0   0.00  15.00  15.00   0.00  15.00  73.00   2.00  72.34   1.00   1.00
# 1   0.00  15.00  14.00   1.00  13.67  71.00   4.00  69.68   1.00   2.00
# 2   0.00  15.00  15.00   0.00  15.00  69.00   6.00  66.99   1.00   3.00
#
#    Der_Mer  Der_Ama  Der_Gnl      Tarih  TotaL  Unified_Name
# ...

# %%
df.describe().T
# Out:
#          count     mean      std     min     25%      50%      75%       max
# NO      402.00    44.19    29.44    1.00   21.00    41.00    62.00    125.00
# Std_No  402.00   341.68   220.17    1.00  185.00   343.00   503.75   3131.00
# LGS     402.00   295.15    92.61   93.98  219.71   302.54   368.95    488.64
# Tur_D   402.00     9.27     2.92    0.00    7.00    10.00    11.00     15.00
# Tur_Y   402.00     5.00     2.75    0.00    3.00     5.00     7.00     13.00
# Tur_N   402.00     7.61     3.64   -2.33    5.00     8.33    10.33     15.00
# Din_D   402.00     7.02     2.28    0.00    6.00     7.00     9.00     10.00
# Din_Y   402.00     2.63     2.12    0.00    1.00     2.00     4.00     10.00
# Din_N   402.00     6.15     2.91   -3.33    4.67     6.33     8.67     10.00
# Tar_D   402.00     6.97     2.30    0.00    6.00     7.00     9.00     10.00
# Tar_Y   402.00     2.78     2.23    0.00    1.00     2.00     4.00     10.00
# ...

# %% [markdown]
# # LGS (Target)

# %%
sns.set(font_scale=1.2)
sns.histplot(data=df, x="LGS",bins=30,kde=True)
# Out:
# <AxesSubplot:xlabel='LGS', ylabel='Count'>

# %%
sns.boxplot(data=df, x="LGS",
            showmeans=True,
            meanprops={"marker":"o",
                       "markerfacecolor":"black",
                       "markeredgecolor":"white",
                       "markersize":"10"});

# %% [markdown]
# **LGS nin dağılımının normal dağılıma yakın olduğu, LGS puanının 220-370 puan aralığında yoğunlaştığı söylenebilir. Örneklemde ektreme değer gözlenmedi**

# %% [markdown]
# ## Std_C

# %%
df.describe(include=object).T
# Out:
#              count unique           top freq
# Std_Name       402    181  ZEYNEP TÜREL    5
# Std_C          402      4            5B  121
# SINAV          402      5     Argon_CDS  125
# Unified_Name   402    167   ZEYNEPTÜREL    5

# %%
df.groupby(["Std_C","SINAV"])[["Std_No"]].count()
# Out:
#                  Std_No
# Std_C SINAV
# 5A    Argon_CDS      30
#       Mozaik_1       20
#       Mozaik_2       23
#       Mozaik_3       14
#       Zeka           22
# 5B    Argon_CDS      33
#       Mozaik_1       22
#       Mozaik_2       25
#       Mozaik_3       20
#       Zeka           21
# 5C    Argon_CDS      29
#       Mozaik_1       20
#       Mozaik_2       25
#       Mozaik_3       11
#       Zeka           19
# 5D    Argon_CDS      33
#       Mozaik_1       11
#       Mozaik_3        9
#       Zeka           15

# %%
plt.figure(figsize=(12,8))
sns.countplot(data=df,x="Std_C");

# %%
sns.countplot(data=df,x="Std_C",hue="SINAV");
plt.legend(loc=(1.05,0.8))

# %% [markdown]
# Sınıf mevcutlarının birbirine yakın olmasına rağmen **5-D** sınıfının sınavlara katılımının az olduğu gözlemlenmiştir. 5-D sınıfının mozaik-2 sınavına katılmadığı görülmektedir. Bir sınavı eksik olmasına rağmen sınavların geneline katılımının az olduğu gözlemlenmektedir.

# %%
fig ,ax = plt.subplots(1,2,figsize=(18,6))
sns.barplot(data=df,x="Std_C",y="LGS",ax=ax[0])
sns.boxplot(data=df,x="Std_C",y="LGS",ax=ax[1],
            showmeans=True,
            meanprops={"marker":"o",
                       "markerfacecolor":"black",
                       "markeredgecolor":"white",
                       "markersize":"10"});

# %%
fig ,ax = plt.subplots(figsize=(18,10))
g = sns.kdeplot(data=df,x="LGS",hue="Std_C",shade=True,bw=0.3)
g.axvline(x=df.LGS.mean(), color='black', linestyle=':', lw=3)
g.axvline(x=np.median(df.LGS), color='blue', linestyle=':', lw=3);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.3 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **5-A** sınıfının tüm sınavlardaki LGS puanı ortalamasının diğer sınıflardan yüksek olduğu, 5-D sınıfı ile arasında bariz fark olduğu görülmektedir.
# 5-A sınıfının LGS puan aralığının diğer sınıflardan daha yüksek olduğu, 5-D sınıfının da diğer sınıflardan daha düşük bir puan aralığına sahip olduğu görülmektedir.
# 5-D sınıfının en yüksek puanınında düşük olduğu gözlemlenmiştir.
# 5.sınıfların LGS puan ortalamasının 300 olduğu gözlemlenmeketdir.

# %% [markdown]
# ## SINAV

# %%
fig, ax = plt.subplots(1,2,figsize=(14,8))

sns.countplot( x= "SINAV", data=df, ax=ax[0])
df["SINAV"].value_counts().plot.pie(autopct="%.1f%%", ax=ax[1], radius=1.1, startangle=0, explode=[0.1,0,0,0,0], shadow=True)
# Out:
# <AxesSubplot:ylabel='SINAV'>

# %%
plt.figure(figsize=(12,8))
ax = sns.countplot( x= "SINAV", data=df, hue="Std_C")
for i in ax.containers:
    ax.bar_label(i)

# %%
fig, ax = plt.subplots(1,2,figsize=(14,8))
sns.barplot(x= "SINAV", data=df, y="LGS", ax=ax[0])
sns.boxplot(x= "SINAV", data=df, y="LGS", ax=ax[1], showmeans=True, meanprops={"marker":"o", "markerfacecolor":"black",
"markeredgecolor":"white", "markersize":"10"});

# %%
plt.figure(figsize=(12,8))
ax = sns.pointplot(x= "SINAV", data=df, y="LGS", hue="Std_C", ci=None, estimator=np.mean);
plt.ylim(200,400)
plt.legend(loc=(1.05,0.8));

# %%
Std_5D = df[(df["SINAV"] == "Mozaik_3") & (df["Std_C"] == "5D")]["Std_No"]

# %%
df[df["Std_No"].isin(Std_5D)].groupby("SINAV")["LGS"].mean()
# Out:
# SINAV
# Argon_CDS   337.01
# Mozaik_1    296.15
# Mozaik_3    318.26
# Zeka        296.70
# Name: LGS, dtype: float64

# %% [markdown]
# Sınav bazında yapılan incelemeler neticesinde;
# Öğrencilerin en fazla katılım gösterdiği sınav Argon iken en az katılım Mozaik-3 sınavına olmuştur. Mozaik-2 sınavına 5-B sınıfı katılım sağlamamıştır.
# Genel manada zaman geçtikçe öğrencilerin denemelere katılımı düşmektedir. Katılım en fazla 5-D ve 5-C sınıfında düşmüştür.
# Sınavlar içinde en yüksek puan ortalaması Mozaik-3 sınavındadır. (Katılımın en az olduğu sınav olması ve düşük not alan öğrencilerin sınavlara girmediği gerçeğiyle bunun gerçek bir yaklaşım olamayacağı söylenebilir)
# Mozaik-3 denemesinde 4 sınıfında ortalama notları birbirine yakınken (birbirine yakın puan alan öğrenciler katılım göstermiş olabilir), Zeka ve Mozaik-1 sınavlarında sınıflar arası ortalama puan dağılımnda skala açıktır. Mozaik-1 sınavı tüm sınavlar arasında puan ortalamasının en düşük olduğu sınavdır.
# 5-D sınıfında Mozaik3 sınavına giren 9 öğrenicinin diğer sınav notlarına bakıldığında sınıf ortalamasının üzerinde öğrenciler olduğu gözlenmekte olup, Mozaik-3 sınavında gerçek bir başarı gösterdikleri söyelenbilir.
# Tablonun genelinde 5-A sınıfının Mozaik-3 denemesi hariç diğer sınavlarda en başarılı sınıf olduğu söylenebilir.
# 5-B ve 5-C sınıfları ortalama puan dağılımında birbirine yakın olup, sınavlar üzerinden değerlendirme yapıldığında sınıf ortalamaları birbirine benzerdir.

# %% [markdown]
# ## Top_N

# %%
#fig, ax = plt.subplots(1,2, figsize=(14,8))
sns.boxplot(data=df, x="Top_N", showmeans=True,
            meanprops={"marker":"o", "markerfacecolor":"black", "markeredgecolor":"white", "markersize":"10"});
#sns.boxplot(data=df, x="LGS", showmeans=True, ax=ax[1],
#            meanprops={"marker":"o", "markerfacecolor":"black", "markeredgecolor":"white", "markersize":"10"});

# %%
sns.regplot(x="Top_N", y="LGS", data=df);

# %% [markdown]
# Toplam netin LGS puanı ile olan doğrusal ilişkisi yadsınamaz bir gerçektir. Scatterplot ile bu ilişki net bir şekilde gözükmektedir.

# %% [markdown]
# ## Mat_N, Fen_N, Tur_N

# %%
fig, ax = plt.subplots(2,3, figsize=(14,12))
sns.histplot(data=df, x="Mat_N",bins=15,kde=True, ax=ax[0,0])
sns.histplot(data=df, x="Fen_N",bins=15,kde=True, ax=ax[0,1], color="orange")
sns.histplot(data=df, x="Tur_N",bins=15,kde=True, ax=ax[0,2], color="red")
sns.boxplot(data=df, y="Mat_N", showmeans=True, ax=ax[1,0],
            meanprops={"marker":"o", "markerfacecolor":"black", "markeredgecolor":"white", "markersize":"10"});
sns.boxplot(data=df, y="Fen_N", showmeans=True, ax=ax[1,1], color="orange",
            meanprops={"marker":"o", "markerfacecolor":"black", "markeredgecolor":"white", "markersize":"10"});
sns.boxplot(data=df, y="Tur_N", showmeans=True, ax=ax[1,2], color="red",
            meanprops={"marker":"o", "markerfacecolor":"black", "markeredgecolor":"white", "markersize":"10"});

# %%
fig, ax = plt.subplots(1,3, figsize=(16,6))
sns.regplot(x="Mat_N", y="LGS", data=df, ax=ax[0]);
sns.regplot(x="Fen_N", y="LGS", data=df, ax=ax[1],color="orange");
sns.regplot(x="Tur_N", y="LGS", data=df, ax=ax[2], color="red");

# %% [markdown]
# Dersler bazında ypılan incelemer neticesinde;
# Matematik, Fen ve Türkçe derslerinde istatistiki olarak herhangi bir ekstrem değer olmadığı görülmektedir.
# Fen netleri normal dağılıma çok yakın bir dağılım göstermekteyken, Matematik normal dağılıma yakın, Türkçe ise sola yaslı (left-skewed) bir dağılım göstermektedir.
# Türkçe dersi net ortalaması 7.5 civarında iken, sınıfın netlerinin en çok toplandığı net 8 civarındadır. Matematikte ve Fen'de ise daha çok 6.5 net ortalamasında toplanmışlardır.
# 3 dersinde LGS puanı ile olan ilişkisi incelendiğinde 3 dersinde LGS ile doğrusal bir ilişki içinde olduğu söylenebilir.

# %% [markdown]
# ## Tar_N, Ing_N, Din_N

# %%
fig, ax = plt.subplots(2,3, figsize=(14,12))
sns.histplot(data=df, x="Tar_N",bins=15,kde=True, ax=ax[0,0])
sns.histplot(data=df, x="Ing_N",bins=15,kde=True, ax=ax[0,1], color="orange")
sns.histplot(data=df, x="Din_N",bins=15,kde=True, ax=ax[0,2], color="red")
sns.boxplot(data=df, y="Tar_N", showmeans=True, ax=ax[1,0],
            meanprops={"marker":"o", "markerfacecolor":"black", "markeredgecolor":"white", "markersize":"10"});
sns.boxplot(data=df, y="Ing_N", showmeans=True, ax=ax[1,1], color="orange",
            meanprops={"marker":"o", "markerfacecolor":"black", "markeredgecolor":"white", "markersize":"10"});
sns.boxplot(data=df, y="Din_N", showmeans=True, ax=ax[1,2], color="red",
            meanprops={"marker":"o", "markerfacecolor":"black", "markeredgecolor":"white", "markersize":"10"});

# %%
df[df["Tar_N"]<-1]
# Out:
#       NO  Std_No               Std_Name Std_C      SINAV    LGS  Tur_D  Tur_Y  \
# 99   100     139        ENES EMRE TANCI    5D  Argon_CDS 198.07   8.00   7.00
# 118  119     624  ** *N  N            D    5C  Argon_CDS 135.46   6.00   9.00
# 120  121     625          EFE ÖZYILM AZ    5D  Argon_CDS 125.90   2.00  13.00
# 121  122     626                RU*ĞA*K    5B  Argon_CDS 124.54   7.00   8.00
# 257   60      99             BORAN EKİM    5B   Mozaik_1 170.21   7.00   8.00
# 269   72     265          ASEL KARAKAYA    5B   Mozaik_1 105.81   0.00   0.00
# 270   73     332      MUHA MET EMİN KAY    5C   Mozaik_1 102.09   0.00   0.00
# 345   75     172            EYMEN POLAT    5A       Zeka 140.97   6.00   9.00
#
#      Tur_N  Din_D  Din_Y  Din_N  Tar_D  Tar_Y  Tar_N  Ing_D  Ing_Y  Ing_N  \
# 99    5.67   6.00   4.00   4.67   0.00  10.00  -3.33   3.00   7.00   0.67
# 118   3.00   2.00   8.00  -0.67   1.00   9.00  -2.00   2.00   8.00  -0.67
# ...

# %%
df[df["Din_N"]<-1]
# Out:
#       NO  Std_No       Std_Name Std_C      SINAV    LGS  Tur_D  Tur_Y  Tur_N  \
# 94    95     542     PAŞA CELEP    5D  Argon_CDS 201.88   8.00   6.00   6.00
# 113  114     223        ELAEKIM    5A  Argon_CDS 156.67   6.00   9.00   3.00
# 117  118     554  YİĞİT KORKMAZ    5D  Argon_CDS 139.10   5.00  10.00   1.67
# 122  123     275       EMİR KOÇ    5D  Argon_CDS 122.50   4.00  11.00   0.33
# 124  125     470    NEHİR   BAL    5A  Argon_CDS  98.16   2.00  12.00  -2.00
# 194   70     265  ASEL KARAKAYA    5B   Mozaik_2 147.57   6.00   9.00   3.00
# 196   72     990     BORAN EKİM    5B   Mozaik_2 116.08   6.00   9.00   3.00
#
#      Din_D  Din_Y  Din_N  Tar_D  Tar_Y  Tar_N  Ing_D  Ing_Y  Ing_N  Mat_D  \
# 94    1.00   9.00  -2.00   5.00   5.00   3.33   2.00   8.00  -0.67   8.00
# 113   0.00  10.00  -3.33   6.00   4.00   4.67   3.00   7.00   0.67   5.00
# 117   1.00   9.00  -2.00   3.00   7.00   0.67   4.00   6.00   2.00   5.00
# ...

# %%
fig, ax = plt.subplots(1,3, figsize=(16,6))
sns.scatterplot(x="Tar_N", y="LGS", data=df, ax=ax[0]);
sns.scatterplot(x="Ing_N", y="LGS", data=df, ax=ax[1],color="orange");
sns.scatterplot(x="Din_N", y="LGS", data=df, ax=ax[2], color="red");

# %% [markdown]
# Dersler bazında ypılan incelemer neticesinde;
# Tarih ve Din derslerinde net ortalamasının daha yüksekte olduğu gerçeğinden hareketle -2 ve altı netler extreme değerler olarak gözükmektedir. Yapılan kontroller ile bunların diğer derslerde olduğu üzere normal olduğu görülmüş ve bu değerlere herhangi bir işlem yapılmamıştır. İngilizce dersinde ise herhangi bir ekstrem değer olmadığı görülmektedir.
# 3 derste sola yatkın(left-skewed) bir grafik göstermektedir.
# 3 ders içerisinde (soru sayısı aynı olduğu için) en yüksek net ortalaması Tarih dersinde olup, en düşük net ortalaması İngilizce dersindedir.
# 3 dersinde LGS puanı ile olan ilişkisi incelendiğinde 3 dersinde LGS ile doğrusala yakın bir ilişki içinde olduğu fakat bu ilişkinin Matematik, Fen ve Türkçe'de olduğu doğrusallığı sağlamadığı, doğrusallıktan uzak çok fazla öğrenci olduğu görülmektedir.

# %% [markdown]
# # Sınıf Sıralaması

# %%
plt.pie()

# %%
count_1df = (df[df["LGS"] > df["LGS"].mean()]["Std_C"].value_counts() / df["Std_C"].value_counts()).to_frame("Ortalama_üstü")
count_1df["Ortalama_altı"] = 1 - count_1df["Ortalama_üstü"]
count_1df.T.plot.pie(
                    subplots=True, layout=(2,2),
                    legend=False,
                    colors=['skyblue','orange','#99ff99','#ffcc99'],
                    autopct='%.1f%%',
                    radius=1.2,
                    title=["5A SINIFI","5B SINIFI","5C SINIFI","5D SINIFI"],
                    pctdistance = 0.3,
                    labeldistance = 0.6,
                    figsize=(14,10));
 
plt.tight_layout()

# %%
count_2 = (df[df["LGS"] > df["LGS"].mean()].groupby("SINAV")["Std_C"].value_counts() / df.groupby("SINAV")["Std_C"].value_counts()).to_frame("ortalama").unstack()
count_2 = count_2.droplevel(axis=1,level=0)
count_2.plot.bar(width=0.8, figsize=(16,8));

# %% [markdown]
# Sınıflardan sınava katılım oranlarının değişkenlik gösterdiği gerçeğinden hareketle, sınıflar bazında oransal olarak LGS ortalamasının üzerinde alan kişi ortalaması en fazla 5A sınıfında olup, onu 5C,5B ve en son 5D sınıfı takip etmektedir.
# Sınavlar bazında yapılan incelemede ise Mozaik-3 sınavı ortalamanın en çok üstüne çıkılan sınav olarak göze çarpmaktadır. Zeka sınavında 5A sınıfı oldukça başarılı bir grafik çizerken, Mozaik_1 sınavı öğrencilerin en düşük başarı gösterdiği sınav denebilir.

# %% [markdown]
# # Ders Bazında Sınıf Sıralaması

# %%
fig, ax = plt.subplots(2,3, figsize=(18,12))
sns.barplot(x="Std_C", y="Mat_N", data=df, ax=ax[0,0])
sns.barplot(x="Std_C", y="Fen_N", data=df, ax=ax[0,1])
sns.barplot(x="Std_C", y="Tur_N", data=df, ax=ax[0,2])
sns.barplot(x="Std_C", y="Tar_N", data=df, ax=ax[1,0])
sns.barplot(x="Std_C", y="Ing_N", data=df, ax=ax[1,1])
sns.barplot(x="Std_C", y="Din_N", data=df, ax=ax[1,2]);

# %% [markdown]
# 1. Matematik dersinde net ortalamasına göre sıralama 5A-5C-5B-5D şeklindedir. 5A net ortalaması oldukça iyi olup, 5D sınıfı belirgin şekilde düşük net ortalamasına sahiptir.
# 2. Fen dersinde net ortalamasına göre sıralama 5A-5B-5C-5D şeklindedir. 5A net ortalaması oldukça iyi olup, 5D sınıfı belirgin şekilde düşük net ortalamasına sahiptir.
# 3. Türkçe dersinde bütün sınıflar benzer not ortalamasına sahiptir.
# 4. Tarih dersinde 5A ve 5C 6,5 net ortalamasına sahipken, 5B ve 5D 5,5 net ortalamasına sahiptir.
# 5. İngilizce dersinde net ortalamasına göre sıralama 5B-5C-5A-5D şeklindedir. 5B net ortalaması oldukça iyi olup, 5D sınıfı belirgin şekilde düşük net ortalamasına sahiptir.
# 6. Din dersinde 5C ve 5A benzer not ortamasına sahipken,5D yine en kötü not ortalamasına sahip sınıf olarak öne çıkmaktadır.

# %% [markdown]
# # Sınıf İçi İlişkiler

# %%
g = sns.kdeplot(data=df,x="Top_N",hue="Std_C",fill=True, bw_adjust=0.7);
g.axvline(x=df.Top_N.mean(), color='black', linestyle=':', lw=3)
g.axvline(x=np.median(df.Top_N), color='blue', linestyle=':', lw=3);

# %%
fig, ax = plt.subplots(3,2, figsize=(16,20))
sns.kdeplot(data=df,x="Mat_N",hue="Std_C",fill=True, bw_adjust=0.6, ax=ax[0,0])
sns.kdeplot(data=df,x="Fen_N",hue="Std_C",fill=True, bw_adjust=0.6, ax=ax[0,1])
sns.kdeplot(data=df,x="Tur_N",hue="Std_C",fill=True, bw_adjust=0.6, ax=ax[1,0])
sns.kdeplot(data=df,x="Tar_N",hue="Std_C",fill=True, bw_adjust=0.6, ax=ax[1,1])
sns.kdeplot(data=df,x="Ing_N",hue="Std_C",fill=True, bw_adjust=0.6, ax=ax[2,0])
sns.kdeplot(data=df,x="Din_N",hue="Std_C",fill=True, bw_adjust=0.6, ax=ax[2,1]);

# %% [markdown]
# Derslerin, sınıf bazında dağılım grafiklerinin incelenmesi neticesinde;
# 1. Toplam netin 40 net olduğundan hareketle 5A'nın büyük yoğunluğunun genel ortalamanın üstünde olduğu, 5D sınıfının büyük yoğunluğunun da ortalamanın altında kaldığı gözlemlenmektedir.
#     Toplam nete göre her sınıfta temelde iki grup olduğu görülmektedir. Bu gruplar;
#     5C sınıfında 20 net ve 47 net,
#     5B sınıfında 30 net ve 50 net,
#     5A sınıfında 40 net ve 58 net,
#     5D sınıfında ise  18 net ve 40 net olmak üzere dağılmaktadır.
# 2. Matematik dersi netleri için 5A sınıfında (2 net ve 10 net) ve 5B sınıfında (1 net ve 6 net) iki grup olduğu söylenebilir.
# 3. Fen dersi netleri için 5B sınıfında (1 net ve 8 net) ve 5D sınıfında ( 3 net ve 7 net) iki grup  olduğu söylenebilir.
# 4. Türkçe dersi netleri sınıfların notlarının normal dağılıma yakın olduğu, sınıf içinde gruplaşma olmadığı söylenebilir.
# 5. Tarih dersi netlerinin genel itibariyle yüksek olduğu, 5B sınıfında (2,5 net ve 7,5 net) ve 5D sınıfında (3 net ve 7 net) iki grup olduğu söylenebilir.
# 6. İngilizce dersi netleri için özellikle 5C sınıfında -1 net ve 9 net olmak üzere 2 grup olduğu söylenebilir.
# 7. Din dersi netleri için ise 5B sınıfında 6 net ve 8,5 nette iki grup, 5A sınıfında ise 6 net ve 9 net olmak üzere yine 2 grup olduğu söylenebilir.

# %% [markdown]
# # En Yüksek ve En Düşük Puanlı 10 Öğrenci

# %%
eniyi10 = df.groupby("Std_No")["LGS"].mean().sort_values(ascending=False).head(10)
endusuk10 = df.groupby("Std_No")["LGS"].mean().sort_values(ascending=False).tail(10)
eniyi10_isim = [df[df["Std_No"] == i]["Std_Name"].mode()[0] for i in eniyi10.index]
endusuk10_isim = [df[df["Std_No"] == i]["Std_Name"].mode()[0] for i in endusuk10.index]

fig, ax = plt.subplots(1,2, figsize=(16,8))
plt.ylim(0,500)
g = sns.barplot(x=eniyi10.index, y=eniyi10.values, ax=ax[0], order=eniyi10.index)
g.set_xticklabels(eniyi10_isim, rotation=90)
g.set_xlabel("Öğrenci İsmi")
p = sns.barplot(x=endusuk10.index, y=endusuk10.values, ax=ax[1], order=endusuk10.index)
p.set_xticklabels(endusuk10_isim, rotation=90)
p.set_xlabel("Öğrenci İsmi");

# %% [markdown]
# # Sınıf Bazında En İyi, En düşük Puanlı Öğr.

# %%
df_sıralama = df.groupby("Std_No").mean().reset_index()
df_sıralama
# Out:
#      Std_No     NO    LGS  Tur_D  Tur_Y  Tur_N  Din_D  Din_Y  Din_N  Tar_D  \
# 0         1  66.00 208.69   6.67   2.33   5.89   5.33   3.67   4.11   6.00
# 1        11  72.33 160.50   5.67   9.33   2.55   4.00   6.00   2.00   3.33
# 2        23  37.50 341.98  10.00   5.00   8.33   9.00   1.00   8.67   8.00
# 3        51  48.00 341.65  11.00   4.00   9.67   8.00   2.00   7.33   5.00
# 4        55  40.33 310.31   9.00   6.00   7.00   7.67   2.33   6.89   9.33
# ..      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 131     625 121.00 125.90   2.00  13.00  -2.33   2.00   8.00  -0.67   1.00
# 132     626 122.00 124.54   7.00   8.00   4.33   2.00   8.00  -0.67   1.00
# 133     627  73.00 158.55   9.00   6.00   7.00   4.00   6.00   2.00   5.00
# 134     990  72.00 116.08   6.00   9.00   3.00   0.00  10.00  -3.33   2.00
# 135    3131  99.00 198.89   6.00   9.00   3.00   7.00   3.00   6.00   7.00
#
# ...

# %%
no_5A = df[df["Std_C"] == "5A"]["Std_No"].unique()
no_5B = df[df["Std_C"] == "5B"]["Std_No"].unique()
no_5C = df[df["Std_C"] == "5C"]["Std_No"].unique()
no_5D = df[df["Std_C"] == "5D"]["Std_No"].unique()
df_sıralama["Std_C"] = df_sıralama["Std_No"].transform(lambda x: "5A" if x in no_5A else ("5B" if x in no_5B else(
                                                        "5C" if x in no_5C else "5D")))

# %%
df_sıralama = df_sıralama.sort_values(by=["Std_C","LGS"], ascending=False)
df5A = df_sıralama[df_sıralama["Std_C"] == "5A"]
df5B = df_sıralama[df_sıralama["Std_C"] == "5B"]
df5C = df_sıralama[df_sıralama["Std_C"] == "5C"]
df5D = df_sıralama[df_sıralama["Std_C"] == "5D"]

fig, ax = plt.subplots(2,4)
sns.barplot(x=df5A["Std_No"].head(5), y=df5A["LGS"].head(5), ax=ax[0,0], order=df5A["Std_No"].head(5) ).set_title("5A En İyi 5")
sns.barplot(x=df5B["Std_No"].head(5), y=df5B["LGS"].head(5), ax=ax[0,1], order=df5B["Std_No"].head(5) ).set_title("5B En İyi 5")
sns.barplot(x=df5C["Std_No"].head(5), y=df5C["LGS"].head(5), ax=ax[0,2], order=df5C["Std_No"].head(5) ).set_title("5C En İyi 5")
sns.barplot(x=df5D["Std_No"].head(5), y=df5D["LGS"].head(5), ax=ax[0,3], order=df5D["Std_No"].head(5) ).set_title("5D En İyi 5")
sns.barplot(x=df5A["Std_No"].tail(5), y=df5A["LGS"].tail(5), ax=ax[1,0], order=df5A["Std_No"].tail(5) ).set_title("5A En Düşük 5")
sns.barplot(x=df5B["Std_No"].tail(5), y=df5B["LGS"].tail(5), ax=ax[1,1], order=df5B["Std_No"].tail(5) ).set_title("5B En Düşük 5")
sns.barplot(x=df5C["Std_No"].tail(5), y=df5C["LGS"].tail(5), ax=ax[1,2], order=df5C["Std_No"].tail(5) ).set_title("5C En Düşük 5")
sns.barplot(x=df5D["Std_No"].tail(5), y=df5D["LGS"].tail(5), ax=ax[1,3], order=df5D["Std_No"].tail(5) ).set_title("5D En Düşük 5")
plt.tight_layout()

# %% [markdown]
# # En Fazla Yanlış Yapılan Ders

# %%
yanlıs_sır = (df.describe().loc["mean",["Tur_Y","Din_Y","Tar_Y","Ing_Y","Mat_Y","Fen_Y"]] / [15,10,10,10,15,15]).sort_values()
yanlıs_sır
# Out:
# Din_Y   0.26
# Tar_Y   0.28
# Ing_Y   0.31
# Tur_Y   0.33
# Mat_Y   0.33
# Fen_Y   0.39
# Name: mean, dtype: float64

# %%
sns.barplot(x= yanlıs_sır.index, y=yanlıs_sır.values)
plt.title("DERS BAZINDA YANLIŞ CEVAP / TOPLAM SORU ORANI", fontsize= 18, pad=30)
plt.xlabel("DERSLER")
plt.ylabel("ORAN")
plt.xticks([0,1,2,3,4,5],labels=["DİN","TARİH","İNGİLİZCE","TÜRKÇE","MATEMATİK","FEN"]);

# %%
yanlıs_df =df.groupby("Std_C")[["Tur_Y","Din_Y","Tar_Y","Ing_Y","Mat_Y","Fen_Y"]].mean() / [15,10,10,10,15,15]
yanlıs_df
# Out:
#        Tur_Y  Din_Y  Tar_Y  Ing_Y  Mat_Y  Fen_Y
# Std_C
# 5A      0.33   0.24   0.24   0.30   0.28   0.35
# 5B      0.33   0.27   0.30   0.26   0.31   0.37
# 5C      0.32   0.26   0.25   0.30   0.36   0.43
# 5D      0.36   0.30   0.34   0.41   0.43   0.43

# %%
fig, ax = plt.subplots(2,2, figsize=(14,10))
sns.barplot(x = yanlıs_df.loc["5A",:].sort_values().index, y= yanlıs_df.loc["5A",:].sort_values().values, ax=ax[0,0]).set_title("5A", pad=20)
sns.barplot(x = yanlıs_df.loc["5B",:].sort_values().index, y= yanlıs_df.loc["5B",:].sort_values().values, ax=ax[0,1]).set_title("5B", pad=20)
sns.barplot(x = yanlıs_df.loc["5C",:].sort_values().index, y= yanlıs_df.loc["5C",:].sort_values().values, ax=ax[1,0]).set_title("5C", pad=20)
sns.barplot(x = yanlıs_df.loc["5D",:].sort_values().index, y= yanlıs_df.loc["5D",:].sort_values().values, ax=ax[1,1]).set_title("5D", pad=20);
plt.tight_layout()

# %% [markdown]
# Ders bazında yanlış sayısının toplam soru sayısına bölünmesi neticesinde ders bazında sıralama elde edilmiş olup,
# 1. Okul genelinde en fazla yanlış soru cevaplama oranı Fen dersinde olup, onu sırasıyla Matematik, Türkçe, İngilizce, Tarih ve Din seyretmeketdir.
# 2. Sınıf bazında yapılan incelemede
#     5A sınıfı genele uygun şekilde en fazla hatayı Fen dersinde yaparken, onu Türkçe ve İngilizce takip etmektedir.
#     5B sınıfı en fazla hatayı Fen dersinde yaparken, onu Türkçe ve Matematik takip etmektedir.
#     5C sınıfı en fazla hatayı Fen dersinde yaparken, onu Matematik ve Türkçe takip etmektedir.
#     5D sınıfı en fazla hatayı Matematik dersinde yaparken, onu Fen ve İngilizce takip etmektedir.

# %% [markdown]
# # En Fazla Net Yapılan Ders

# %%
net_sır = (df.describe().loc["mean",["Tur_N","Din_N","Tar_N","Ing_N","Mat_N","Fen_N"]] / [15,10,10,10,15,15]).sort_values()
net_sır
# Out:
# Fen_N   0.42
# Mat_N   0.42
# Tur_N   0.51
# Ing_N   0.55
# Tar_N   0.60
# Din_N   0.61
# Name: mean, dtype: float64

# %%
sns.barplot(x= net_sır.index, y=net_sır.values)
plt.title("DERS BAZINDA NET / TOPLAM SORU ORANI", fontsize= 18, pad=30)
plt.xlabel("DERSLER")
plt.ylabel("ORAN")
plt.xticks([0,1,2,3,4,5],labels=["FEN","MATEMATİK","TÜRKÇE","İNGİLİZCE","TARİH","DİN"]);

# %%
net_df =df.groupby("Std_C")[["Tur_N","Din_N","Tar_N","Ing_N","Mat_N","Fen_N"]].mean()  / [15,10,10,10,15,15]
net_df
# Out:
#        Tur_N  Din_N  Tar_N  Ing_N  Mat_N  Fen_N
# Std_C
# 5A      0.52   0.64   0.66   0.54   0.50   0.47
# 5B      0.50   0.60   0.56   0.63   0.41   0.41
# 5C      0.51   0.64   0.64   0.57   0.43   0.40
# 5D      0.49   0.57   0.53   0.41   0.32   0.37

# %%
fig, ax = plt.subplots(2,2, figsize=(14,10))
sns.barplot(x = net_df.loc["5A",:].sort_values().index, y= net_df.loc["5A",:].sort_values().values, ax=ax[0,0]).set_title("5A", pad=20)
sns.barplot(x = net_df.loc["5B",:].sort_values().index, y= net_df.loc["5B",:].sort_values().values, ax=ax[0,1]).set_title("5B", pad=20)
sns.barplot(x = net_df.loc["5C",:].sort_values().index, y= net_df.loc["5C",:].sort_values().values, ax=ax[1,0]).set_title("5C", pad=20)
sns.barplot(x = net_df.loc["5D",:].sort_values().index, y= net_df.loc["5D",:].sort_values().values, ax=ax[1,1]).set_title("5D", pad=20);
plt.tight_layout()

# %% [markdown]
# Ders bazında net sayısının toplam soru sayısına bölünmesi neticesinde ders bazında sıralama elde edilmiş olup,
# 1. Okul genelinde en fazla net oranı Din dersinde olup, onu sırasıyla Tarih, İngilizce, Türkçe, Matematik ve Fen seyretmeketdir.
# 2. Sınıf bazında yapılan incelemede;
#     5A sınıfı en fazla neti Tarih dersinde yaparken, en az neti  Fen ve Matematik dersinde yapmaktadır.
#     5B sınıfı en fazla neti İngilizce dersinde yaparken, en az neti  Matematik ve Fen dersinde yapmaktadır.
#     5C sınıfı en fazla neti Tarih dersinde yaparken, en az neti  Fen ve Matematik dersinde yapmaktadır.
#     5D sınıfı en fazla neti Din dersinde yaparken, en az neti  Mateamatik ve Fen dersinde yapmaktadır.
